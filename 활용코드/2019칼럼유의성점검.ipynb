# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %% [markdown]
# 런타임 재시작

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'NanumGothic'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 2019

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("/content/drive/MyDrive/KOPIS공모전/데이터/EDA용 데이터/20191224.xlsx")
df.head()
# Out:
#    좌석수      공연코드              공연일시             예매/취소일시  예매/취소구분  예매/취소매수  \
# 0  160  PF350480  2023-12-24 10:30 2023-12-23 13:56:00        1        1
# 1  160  PF350480  2023-12-24 10:30 2023-12-23 13:56:00        1        1
# 2  160  PF350480  2023-12-24 10:30 2023-11-29 20:23:00        1        1
# 3  160  PF350480  2023-12-24 10:30 2023-11-29 20:23:00        1        1
# 4  160  PF350480  2023-12-24 10:30 2023-11-29 20:23:00        1        1
#
#    예매/취소금액 예매/취소방식명(관리시스템)  할인금액 할인종류명(전송처)  ...  \
# 0    35000             모바일     0        NaN  ...
# 1    35000             모바일     0        NaN  ...
# 2    22900               웹     0        NaN  ...
# 3    22900               웹     0        NaN  ...
# 4    22900               웹     0        NaN  ...
#
#                                  출연진내용  아동공연 여부  내한공연 여부 오픈런 여부  \
# 0  정해빈, 신서진, 김보람, 신희진, 이세형, 이시운, 류권하 등        N        N      Y
# 1  정해빈, 신서진, 김보람, 신희진, 이세형, 이시운, 류권하 등        N        N      Y
# 2  정해빈, 신서진, 김보람, 신희진, 이세형, 이시운, 류권하 등        N        N      Y
# 3  정해빈, 신서진, 김보람, 신희진, 이세형, 이시운, 류권하 등        N        N      Y
# 4  정해빈, 신서진, 김보람, 신희진, 이세형, 이시운, 류권하 등        N        N      Y
#
#                판매시작일시               판매종료일시       좌석등급 극장규모 재관람 조기예매
# 0 2023-11-24 11:13:53  2099/12/31 23:59:59  전석(35000)    1   0    0
# 1 2023-11-24 11:13:53  2099/12/31 23:59:59  전석(35000)    1   0    0
# 2 2023-11-06 09:00:00  2023/12/24 09:00:00  전석(35000)    1   0    0
# 3 2023-11-06 09:00:00  2023/12/24 09:00:00  전석(35000)    1   0    0
# 4 2023-11-06 09:00:00  2023/12/24 09:00:00  전석(35000)    1   0    0
#
# [5 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['좌석수', '공연코드', '공연일시', '예매/취소일시', '예매/취소구분', '예매/취소매수', '예매/취소금액',
#        '예매/취소방식명(관리시스템)', '할인금액', '할인종류명(전송처)', '장당금액', '성별', '연령', '공연시작일자',
#        '공연종료일자', '장르명', '공연지역명', '출연진내용', '아동공연 여부', '내한공연 여부', '오픈런 여부',
#        '판매시작일시', '판매종료일시', '좌석등급', '극장규모', '재관람', '조기예매'],
#       dtype='object')

# %%
# 일시 변수 결측치 확인
# 예매취소일시
df['예매/취소일시'].value_counts()
# Out:
# 예매/취소일시
# 2023-11-22 15:00:00    222
# 2023-11-21 14:02:00    216
# 2023-11-23 15:00:00    208
# 2023-11-15 13:01:00    193
# 2023-11-21 14:04:00    171
#                       ...
# 2023-12-12 06:58:00      1
# 2023-12-12 21:45:00      1
# 2023-10-27 23:40:00      1
# 2023-12-11 20:45:00      1
# 2023-11-03 01:10:00      1
# Name: count, Length: 32354, dtype: int64

# %%
# 공연일시
df['공연일시'].value_counts()
# Out:
# 공연일시
# 2023-12-24 14:00    32873
# 2023-12-24 19:00    15697
# 2023-12-24 18:00    11085
# 2023-12-24 15:00     8696
# 2023-12-24 18:30     5543
# 2023-12-24 17:00     4529
# 2023-12-24 13:00     2424
# 2023-12-24 15:30     1887
# 2023-12-24 16:00     1862
# 2023-12-24 20:00     1511
# 2023-12-24 16:30     1408
# 2023-12-24 17:30      840
# 2023-12-24 14:30      781
# 2023-12-24 11:00      615
# 2023-12-24 13:30      541
# 2023-12-24 19:30      518
# 2023-12-24 11:30      442
# 2023-12-24 12:00      386
# 2023-12-24 21:00      381
# 2023-12-24 15:20      302
# 2023-12-24 19:20      249
# 2023-12-24 20:30      247
# 2023-12-24 15:10      167
# 2023-12-24 21:30      163
# 2023-12-24 17:50      162
# 2023-12-24 16:10      115
# 2023-12-24 12:30      113
# 2023-12-24 17:20      110
# 2023-12-24 15:50      108
# 2023-12-24 18:20      101
# 2023-12-24 19:10       94
# 2023-12-24 11:50       90
# 2023-12-24 13:40       84
# 2023-12-24 16:20       75
# 2023-12-24 15:40       75
# 2023-12-24 14:50       68
# 2023-12-24 10:30       57
# 2023-12-24 11:40       56
# 2023-12-24 19:40       55
# 2023-12-24 17:10       54
# 2023-12-24 20:50       42
# 2023-12-24 13:20       38
# 2023-12-24 16:15       38
# 2023-12-24 20:10       34
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94716 entries, 0 to 94715
# Data columns (total 27 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   좌석수              94716 non-null  int64
#  1   공연코드             94716 non-null  object
#  2   공연일시             94716 non-null  object
#  3   예매/취소일시          94716 non-null  datetime64[ns]
#  4   예매/취소구분          94716 non-null  int64
#  5   예매/취소매수          94716 non-null  int64
#  6   예매/취소금액          94716 non-null  int64
#  7   예매/취소방식명(관리시스템)  94716 non-null  object
#  8   할인금액             94716 non-null  int64
#  9   할인종류명(전송처)       36609 non-null  object
#  10  장당금액             94716 non-null  int64
#  11  성별               94716 non-null  int64
#  12  연령               94716 non-null  int64
#  13  공연시작일자           94716 non-null  object
#  14  공연종료일자           94716 non-null  object
#  15  장르명              94716 non-null  object
#  16  공연지역명            94716 non-null  object
#  17  출연진내용            79796 non-null  object
#  18  아동공연 여부          94716 non-null  object
#  19  내한공연 여부          94716 non-null  object
#  20  오픈런 여부           94716 non-null  object
#  21  판매시작일시           92740 non-null  datetime64[ns]
#  22  판매종료일시           94716 non-null  object
#  23  좌석등급             94716 non-null  object
#  24  극장규모             94716 non-null  int64
#  25  재관람              94716 non-null  int64
#  26  조기예매             94716 non-null  int64
# dtypes: datetime64[ns](2), int64(11), object(14)
# memory usage: 19.5+ MB

# %%
# 일시 인코딩
# 날짜 및 시간 데이터 인코딩
# 공연일시
df['공연일시'] = pd.to_datetime(df['공연일시'])
df['공연일시_시간'] = df['공연일시'].dt.hour


# 공연시작일자
# 날짜 및 시간 데이터 인코딩
df['공연시작일자'] = pd.to_datetime(df['공연시작일자'])
df['공연시작일자_연'] = df['공연시작일자'].dt.year
df['공연시작일자_월'] = df['공연시작일자'].dt.month
df['공연시작일자_일'] = df['공연시작일자'].dt.day

# 공연종료일자
# 날짜 및 시간 데이터 인코딩
df['공연종료일자'] = pd.to_datetime(df['공연종료일자'])
df['공연종료일자_연'] = df['공연종료일자'].dt.year
df['공연종료일자_월'] = df['공연종료일자'].dt.month
df['공연종료일자_일'] = df['공연종료일자'].dt.day

# %%
df_play=df[df['장르명']=='연극']
df_musical=df[df['장르명']=='뮤지컬']

# %%
# 스타배우 칼럼 만들기
lst=['최정원', '고준희', '신성록', '차승원', '진선규', '엄기준', '양지원', '나문희', '봉태규', '김선영', '김수미', '고두심', '염혜란',
     '문소리', '박정원', '박은석', '박해수', '박소담', '정성일', '지현준', '이순재', '신구', '홍승안', '정휘', '전성우', '박정복', '전동석',
     '강홍석', '조승우', '옥주현', '정선아', '민경아', '김선영', '최재림', '전미도', '카이', '김준수', '홍강호', '박효신', '박강현', '정성화', '규현',
     '박은태', '박성훈', '조정석', '김승우', '지창욱', '홍광호', '신영숙', '차지연', '지창욱', '한지상', '마이클리', '김소현', '박건형', '윤공주', '바다', '서범석', '아이비']

# 스타배우 칼럼 추가
df_play['스타배우'] = df_play['출연진내용'].apply(
    lambda x: 1 if isinstance(x, str) and any(actor in x.split(', ') for actor in lst) else 0
)


df_musical['스타배우'] = df_musical['출연진내용'].apply(
    lambda x: 1 if isinstance(x, str) and any(actor in x.split(', ') for actor in lst) else 0
)
# Out:
# <ipython-input-11-ef22112668e2>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_play['스타배우'] = df_play['출연진내용'].apply(
# <ipython-input-11-ef22112668e2>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_musical['스타배우'] = df_musical['출연진내용'].apply(

# %%
df_play.columns
# Out:
# Index(['좌석수', '공연코드', '공연일시', '예매/취소일시', '예매/취소구분', '예매/취소매수', '예매/취소금액',
#        '예매/취소방식명(관리시스템)', '할인금액', '할인종류명(전송처)', '장당금액', '성별', '연령', '공연시작일자',
#        '공연종료일자', '장르명', '공연지역명', '출연진내용', '아동공연 여부', '내한공연 여부', '오픈런 여부',
#        '판매시작일시', '판매종료일시', '좌석등급', '극장규모', '재관람', '조기예매', '공연일시_시간',
#        '공연시작일자_연', '공연시작일자_월', '공연시작일자_일', '공연종료일자_연', '공연종료일자_월', '공연종료일자_일',
#        '스타배우'],
#       dtype='object')

# %%
df['예매/취소방식명(관리시스템)'].value_counts()
# Out:
# 예매/취소방식명(관리시스템)
# 모바일    64571
# 웹      30145
# Name: count, dtype: int64

# %% [markdown]
# # 티켓 가격 종속변수 회귀분석

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ### 종속변수 : 장당금액
#
#
# 독립변수 : ['좌석수', '공연일시', '예매/취소금액',
#        '예매/취소방식명(관리시스템)', '할인금액', '할인종류명(전송처)', '장당금액', '성별', '연령', '공연시작일자',
#        '공연종료일자', '공연지역명', '출연진내용', '아동공연 여부', '내한공연 여부', '오픈런 여부',
#        '판매시작일시', '판매종료일시', '극장규모', '재관람', '조기예매'],

# %%
# 장당금액 살펴보기
plt.figure(figsize=(10,6))
sns.histplot(df_play['장당금액'])
plt.show()

# %%
# 장당금액 살펴보기
plt.figure(figsize=(10,6))
sns.histplot(df_musical['장당금액'])
plt.show()

# %%
# 인코딩
df_play = pd.get_dummies(df_play, columns=['공연지역명', '예매/취소방식명(관리시스템)','내한공연 여부','오픈런 여부'],
                         prefix=['공연지역명', '예매/취소방식명(관리시스템)','내한공연 여부','오픈런 여부'])
df_musical = pd.get_dummies(df_musical, columns=['공연지역명', '예매/취소방식명(관리시스템)','내한공연 여부','오픈런 여부'],
                            prefix=['공연지역명', '예매/취소방식명(관리시스템)','내한공연 여부','오픈런 여부'])

# %%
df_play.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34480 entries, 0 to 94715
# Data columns (total 43 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   좌석수                  34480 non-null  int64
#  1   공연코드                 34480 non-null  object
#  2   공연일시                 34480 non-null  datetime64[ns]
#  3   예매/취소일시              34480 non-null  datetime64[ns]
#  4   예매/취소구분              34480 non-null  int64
#  5   예매/취소매수              34480 non-null  int64
#  6   예매/취소금액              34480 non-null  int64
#  7   할인금액                 34480 non-null  int64
#  8   할인종류명(전송처)           20176 non-null  object
#  9   장당금액                 34480 non-null  int64
#  10  성별                   34480 non-null  int64
#  11  연령                   34480 non-null  int64
#  12  공연시작일자               34480 non-null  datetime64[ns]
#  13  공연종료일자               34480 non-null  datetime64[ns]
#  14  장르명                  34480 non-null  object
#  15  출연진내용                26125 non-null  object
#  16  아동공연 여부              34480 non-null  object
#  17  판매시작일시               33467 non-null  datetime64[ns]
#  18  판매종료일시               34480 non-null  object
#  19  좌석등급                 34480 non-null  object
#  20  극장규모                 34480 non-null  int64
#  21  재관람                  34480 non-null  int64
#  22  조기예매                 34480 non-null  int64
#  23  공연일시_시간              34480 non-null  int32
#  24  공연시작일자_연             34480 non-null  int32
#  25  공연시작일자_월             34480 non-null  int32
#  26  공연시작일자_일             34480 non-null  int32
#  27  공연종료일자_연             34480 non-null  int32
#  28  공연종료일자_월             34480 non-null  int32
#  29  공연종료일자_일             34480 non-null  int32
#  30  스타배우                 34480 non-null  int64
#  31  공연지역명_강원도            34480 non-null  bool
#  32  공연지역명_경기도            34480 non-null  bool
#  33  공연지역명_경상도            34480 non-null  bool
#  34  공연지역명_서울             34480 non-null  bool
#  35  공연지역명_전라도            34480 non-null  bool
#  36  공연지역명_제주도            34480 non-null  bool
#  37  공연지역명_충청도            34480 non-null  bool
#  38  예매/취소방식명(관리시스템)_모바일  34480 non-null  bool
#  39  예매/취소방식명(관리시스템)_웹    34480 non-null  bool
#  40  내한공연 여부_N            34480 non-null  bool
#  41  오픈런 여부_N             34480 non-null  bool
#  42  오픈런 여부_Y             34480 non-null  bool
# dtypes: bool(12), datetime64[ns](5), int32(7), int64(12), object(7)
# memory usage: 7.9+ MB

# %%
# 수치형 데이터만 선택
df_numeric_play = df_play.select_dtypes(include=['int64', 'int32', 'float64', 'bool'])

# 상관관계 행렬 계산 및 히트맵 그리기
plt.figure(figsize=(12, 8))
sns.heatmap(df_numeric_play.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap of Numerical Features')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 수치형 데이터만 선택
df_numeric_musical = df_musical.select_dtypes(include=['int64', 'int32', 'float64', 'bool'])

# 상관관계 행렬 계산 및 히트맵 그리기
plt.figure(figsize=(12, 8))
sns.heatmap(df_numeric_musical.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap of Numerical Features')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df_play.columns
# Out:
# Index(['좌석수', '공연코드', '공연일시', '예매/취소일시', '예매/취소구분', '예매/취소매수', '예매/취소금액',
#        '할인금액', '할인종류명(전송처)', '장당금액', '성별', '연령', '공연시작일자', '공연종료일자', '장르명',
#        '출연진내용', '아동공연 여부', '판매시작일시', '판매종료일시', '좌석등급', '극장규모', '재관람', '조기예매',
#        '공연일시_시간', '공연시작일자_연', '공연시작일자_월', '공연시작일자_일', '공연종료일자_연', '공연종료일자_월',
#        '공연종료일자_일', '스타배우', '공연지역명_강원도', '공연지역명_경기도', '공연지역명_경상도', '공연지역명_서울',
#        '공연지역명_전라도', '공연지역명_제주도', '공연지역명_충청도', '예매/취소방식명(관리시스템)_모바일',
#        '예매/취소방식명(관리시스템)_웹', '내한공연 여부_N', '오픈런 여부_N', '오픈런 여부_Y'],
#       dtype='object')

# %%
df_musical.columns
# Out:
# Index(['좌석수', '공연코드', '공연일시', '예매/취소일시', '예매/취소구분', '예매/취소매수', '예매/취소금액',
#        '할인금액', '할인종류명(전송처)', '장당금액', '성별', '연령', '공연시작일자', '공연종료일자', '장르명',
#        '출연진내용', '아동공연 여부', '판매시작일시', '판매종료일시', '좌석등급', '극장규모', '재관람', '조기예매',
#        '공연일시_시간', '공연시작일자_연', '공연시작일자_월', '공연시작일자_일', '공연종료일자_연', '공연종료일자_월',
#        '공연종료일자_일', '스타배우', '공연지역명_강원도', '공연지역명_경기도', '공연지역명_경상도', '공연지역명_서울',
#        '공연지역명_전라도', '공연지역명_제주도', '공연지역명_충청도', '예매/취소방식명(관리시스템)_모바일',
#        '예매/취소방식명(관리시스템)_웹', '내한공연 여부_N', '내한공연 여부_Y', '오픈런 여부_N', '오픈런 여부_Y'],
#       dtype='object')

# %% [markdown]
# 독립변수 :['좌석수',
#        '할인금액','성별', '연령', '극장규모', '재관람', '조기예매',
#        '공연일시_시간', '공연시작일자_연', '공연시작일자_월', '공연시작일자_일', '공연종료일자_연', '공연종료일자_월',
#        '공연종료일자_일', '스타배우', '공연지역명_강원도', '공연지역명_경기도', '공연지역명_경상도', '공연지역명_서울',
#        '공연지역명_전라도', '공연지역명_제주도', '공연지역명_충청도', '예매/취소방식명(관리시스템)_모바일',
#        '예매/취소방식명(관리시스템)_웹', '내한공연 여부_N', '오픈런 여부_N', '오픈런 여부_Y']

# %%
# 연극
# 독립변수와 종속변수 설정
X_play = df_play[['좌석수', '할인금액','성별', '연령', '극장규모', '재관람', '조기예매', '공연일시_시간', '공연시작일자_연', '공연시작일자_월', '공연시작일자_일', '공연종료일자_연', '공연종료일자_월', '공연종료일자_일', '스타배우', '공연지역명_강원도', '공연지역명_경기도', '공연지역명_경상도', '공연지역명_서울', '공연지역명_전라도', '공연지역명_제주도', '공연지역명_충청도',
                  '예매/취소방식명(관리시스템)_모바일', '예매/취소방식명(관리시스템)_웹', '내한공연 여부_N', '오픈런 여부_N', '오픈런 여부_Y']]

y_play = df_play['장당금액']

# Train-Test Split
X_train_p, X_test_p, y_train_p, y_test_p = train_test_split(X_play, y_play, test_size=0.2, random_state=42)

# 회귀모델 학습
model = LinearRegression()
model.fit(X_train_p, y_train_p)

# 테스트 데이터로 예측
y_pred_p = model.predict(X_test_p)

# 모델 평가
mse = mean_squared_error(y_test_p, y_pred_p)
r2 = r2_score(y_test_p, y_pred_p)

print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 109263635.99201205
# R-squared: 0.3751963460592479

# %%
import numpy as np
import statsmodels.api as sm

# 모든 변수를 float64로 변환
X_train_float = X_train_p.astype(np.float64)
y_train_float = y_train_p.astype(np.float64)

# 상수항 추가 (절편을 포함하기 위해 필요)
X_train_sm = sm.add_constant(X_train_float)

# OLS(Ordinary Least Squares) 모델 적합
model_sm = sm.OLS(y_train_float, X_train_sm).fit()

# 회귀 분석 요약 출력
print(model_sm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   장당금액   R-squared:                       0.366
# Model:                            OLS   Adj. R-squared:                  0.366
# Method:                 Least Squares   F-statistic:                     692.4
# Date:                Mon, 19 Aug 2024   Prob (F-statistic):               0.00
# Time:                        05:57:54   Log-Likelihood:            -2.9421e+05
# No. Observations:               27584   AIC:                         5.885e+05
# Df Residuals:                   27560   BIC:                         5.887e+05
# Df Model:                          23
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# 좌석수                    -3.1385      0.599     -5.239      0.000      -4.313      -1.964
# 할인금액                    0.7993      0.008     98.960      0.000       0.783       0.815
# 성별                    351.2229    118.999      2.951      0.003     117.979     584.467
# 연령                     -1.9429      0.140    -13.920      0.000      -2.216      -1.669
# 극장규모                 4525.2739    194.912     23.217      0.000    4143.237    4907.311
# 재관람                 -4554.3742    916.618     -4.969      0.000   -6350.992   -2757.757
# 조기예매                   70.2339    165.329      0.425      0.671    -253.819     394.287
# 공연일시_시간              -187.0365     28.207     -6.631      0.000    -242.324    -131.749
# 공연시작일자_연              395.1551     27.772     14.228      0.000     340.720     449.590
# 공연시작일자_월             -105.5234     31.197     -3.382      0.001    -166.672     -44.375
# 공연시작일자_일              -35.8003      8.049     -4.448      0.000     -51.576     -20.024
# 공연종료일자_연             1.082e+04    609.965     17.732      0.000    9620.441     1.2e+04
# 공연종료일자_월              188.4268     57.301      3.288      0.001      76.113     300.740
# 공연종료일자_일               58.6624     10.796      5.434      0.000      37.502      79.823
# 스타배우                 5116.4388    396.911     12.891      0.000    4338.472    5894.405
# 공연지역명_강원도           -1.523e+06    8.3e+04    -18.357      0.000   -1.69e+06   -1.36e+06
# 공연지역명_경기도            -1.52e+06    8.3e+04    -18.315      0.000   -1.68e+06   -1.36e+06
# 공연지역명_경상도           -1.515e+06    8.3e+04    -18.250      0.000   -1.68e+06   -1.35e+06
# 공연지역명_서울            -1.511e+06    8.3e+04    -18.195      0.000   -1.67e+06   -1.35e+06
# 공연지역명_전라도           -1.513e+06    8.3e+04    -18.229      0.000   -1.68e+06   -1.35e+06
# 공연지역명_제주도           -1.476e+06   8.32e+04    -17.743      0.000   -1.64e+06   -1.31e+06
# 공연지역명_충청도           -1.514e+06    8.3e+04    -18.240      0.000   -1.68e+06   -1.35e+06
# 예매/취소방식명(관리시스템)_모바일 -5.286e+06   2.91e+05    -18.191      0.000   -5.86e+06   -4.72e+06
# 예매/취소방식명(관리시스템)_웹   -5.286e+06   2.91e+05    -18.189      0.000   -5.86e+06   -4.72e+06
# 내한공연 여부_N           -1.057e+07   5.81e+05    -18.190      0.000   -1.17e+07   -9.43e+06
# 오픈런 여부_N            -5.283e+06   2.91e+05    -18.183      0.000   -5.85e+06   -4.71e+06
# 오픈런 여부_Y            -5.289e+06   2.91e+05    -18.198      0.000   -5.86e+06   -4.72e+06
# ==============================================================================
# Omnibus:                    14045.012   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           288135.373
# Skew:                           1.987   Prob(JB):                         0.00
# Kurtosis:                      18.327   Cond. No.                     1.21e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.13e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# **조기예매 유의 X**

# %%
# 뮤지컬
# 연극
# 독립변수와 종속변수 설정
X_mus = df_musical[['좌석수', '할인금액','성별', '연령', '극장규모', '재관람', '조기예매', '공연일시_시간', '공연시작일자_연', '공연시작일자_월', '공연시작일자_일', '공연종료일자_연', '공연종료일자_월', '공연종료일자_일', '스타배우', '공연지역명_강원도', '공연지역명_경기도', '공연지역명_경상도', '공연지역명_서울', '공연지역명_전라도', '공연지역명_제주도', '공연지역명_충청도',
                  '예매/취소방식명(관리시스템)_모바일', '예매/취소방식명(관리시스템)_웹', '내한공연 여부_Y','내한공연 여부_N', '오픈런 여부_N', '오픈런 여부_Y']]

y_mus = df_musical['장당금액']

# Train-Test Split
X_train_m, X_test_m, y_train_m, y_test_m = train_test_split(X_mus, y_mus, test_size=0.2, random_state=42)

# 회귀모델 학습
model = LinearRegression()
model.fit(X_train_m, y_train_m)

# 테스트 데이터로 예측
y_pred_m = model.predict(X_test_m)

# 모델 평가
mse = mean_squared_error(y_test_m, y_pred_m)
r2 = r2_score(y_test_m, y_pred_m)

print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 967078702.5111995
# R-squared: 0.5944887473418516

# %%
import numpy as np
import statsmodels.api as sm

# 모든 변수를 float64로 변환
X_train_float = X_train_m.astype(np.float64)
y_train_float = y_train_m.astype(np.float64)

# 상수항 추가 (절편을 포함하기 위해 필요)
X_train_sm = sm.add_constant(X_train_float)

# OLS(Ordinary Least Squares) 모델 적합
model_sm = sm.OLS(y_train_float, X_train_sm).fit()

# 회귀 분석 요약 출력
print(model_sm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   장당금액   R-squared:                       0.594
# Model:                            OLS   Adj. R-squared:                  0.594
# Method:                 Least Squares   F-statistic:                     2935.
# Date:                Mon, 19 Aug 2024   Prob (F-statistic):               0.00
# Time:                        05:57:54   Log-Likelihood:            -5.6686e+05
# No. Observations:               48188   AIC:                         1.134e+06
# Df Residuals:                   48163   BIC:                         1.134e+06
# Df Model:                          24
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const               -4.946e+07   2.53e+06    -19.574      0.000   -5.44e+07   -4.45e+07
# 좌석수                    62.0494      0.688     90.136      0.000      60.700      63.399
# 할인금액                    0.5491      0.019     28.163      0.000       0.511       0.587
# 성별                   1979.9728    268.470      7.375      0.000    1453.768    2506.178
# 연령                      0.9479      0.357      2.652      0.008       0.247       1.648
# 극장규모                 1.422e+04    447.299     31.794      0.000    1.33e+04    1.51e+04
# 재관람                  4550.8787   2137.578      2.129      0.033     361.198    8740.560
# 조기예매                 4748.0823    301.442     15.751      0.000    4157.252    5338.913
# 공연일시_시간               352.2426     65.260      5.398      0.000     224.333     480.152
# 공연시작일자_연               1.4e+04    882.339     15.871      0.000    1.23e+04    1.57e+04
# 공연시작일자_월            -2406.6357    224.549    -10.718      0.000   -2846.755   -1966.516
# 공연시작일자_일             -340.9850     23.353    -14.602      0.000    -386.757    -295.213
# 공연종료일자_연             5.062e+04   3092.042     16.371      0.000    4.46e+04    5.67e+04
# 공연종료일자_월             3560.3350    289.819     12.285      0.000    2992.286    4128.384
# 공연종료일자_일              525.9079     23.348     22.525      0.000     480.146     571.670
# 스타배우                 2225.9726    411.524      5.409      0.000    1419.381    3032.565
# 공연지역명_강원도            -7.05e+06   3.61e+05    -19.505      0.000   -7.76e+06   -6.34e+06
# 공연지역명_경기도           -7.087e+06   3.61e+05    -19.615      0.000    -7.8e+06   -6.38e+06
# 공연지역명_경상도           -7.082e+06   3.61e+05    -19.598      0.000   -7.79e+06   -6.37e+06
# 공연지역명_서울            -7.066e+06   3.62e+05    -19.539      0.000   -7.77e+06   -6.36e+06
# 공연지역명_전라도           -7.092e+06   3.61e+05    -19.625      0.000    -7.8e+06   -6.38e+06
# 공연지역명_제주도           -6.977e+06   3.58e+05    -19.471      0.000   -7.68e+06   -6.27e+06
# 공연지역명_충청도           -7.104e+06   3.61e+05    -19.657      0.000   -7.81e+06    -6.4e+06
# 예매/취소방식명(관리시스템)_모바일 -2.473e+07   1.26e+06    -19.573      0.000   -2.72e+07   -2.23e+07
# 예매/취소방식명(관리시스템)_웹   -2.473e+07   1.26e+06    -19.574      0.000   -2.72e+07   -2.23e+07
# 내한공연 여부_Y           -2.468e+07   1.26e+06    -19.535      0.000   -2.72e+07   -2.22e+07
# 내한공연 여부_N           -2.478e+07   1.26e+06    -19.612      0.000   -2.73e+07   -2.23e+07
# 오픈런 여부_N            -2.473e+07   1.26e+06    -19.575      0.000   -2.72e+07   -2.23e+07
# 오픈런 여부_Y            -2.473e+07   1.26e+06    -19.572      0.000   -2.72e+07   -2.23e+07
# ==============================================================================
# Omnibus:                     2206.283   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2545.480
# Skew:                          -0.532   Prob(JB):                         0.00
# Kurtosis:                       3.368   Cond. No.                     1.50e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.74e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# **전부 유의**

# %% [markdown]
# ### 종속변수 : 예매/취소 금액

# %%
# 연극
# 독립변수와 종속변수 설정
X_play = df_play[['좌석수', '할인금액','성별', '연령', '극장규모', '재관람', '조기예매', '공연일시_시간', '공연시작일자_연', '공연시작일자_월', '공연시작일자_일', '공연종료일자_연', '공연종료일자_월', '공연종료일자_일', '스타배우', '공연지역명_강원도', '공연지역명_경기도', '공연지역명_경상도', '공연지역명_서울', '공연지역명_전라도', '공연지역명_제주도', '공연지역명_충청도',
                  '예매/취소방식명(관리시스템)_모바일', '예매/취소방식명(관리시스템)_웹', '내한공연 여부_N', '오픈런 여부_N', '오픈런 여부_Y']]

y_play = df_play['예매/취소금액']

# Train-Test Split
X_train_p, X_test_p, y_train_p, y_test_p = train_test_split(X_play, y_play, test_size=0.2, random_state=42)

# 회귀모델 학습
model = LinearRegression()
model.fit(X_train_p, y_train_p)

# 테스트 데이터로 예측
y_pred_p = model.predict(X_test_p)

# 모델 평가
mse = mean_squared_error(y_test_p, y_pred_p)
r2 = r2_score(y_test_p, y_pred_p)

print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 108111545.11234766
# R-squared: 0.2467669202098779

# %%
import numpy as np
import statsmodels.api as sm

# 모든 변수를 float64로 변환
X_train_float = X_train_p.astype(np.float64)
y_train_float = y_train_p.astype(np.float64)

# 상수항 추가 (절편을 포함하기 위해 필요)
X_train_sm = sm.add_constant(X_train_float)

# OLS(Ordinary Least Squares) 모델 적합
model_sm = sm.OLS(y_train_float, X_train_sm).fit()

# 회귀 분석 요약 출력
print(model_sm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                예매/취소금액   R-squared:                       0.247
# Model:                            OLS   Adj. R-squared:                  0.247
# Method:                 Least Squares   F-statistic:                     393.9
# Date:                Mon, 19 Aug 2024   Prob (F-statistic):               0.00
# Time:                        05:57:55   Log-Likelihood:            -2.9403e+05
# No. Observations:               27584   AIC:                         5.881e+05
# Df Residuals:                   27560   BIC:                         5.883e+05
# Df Model:                          23
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# 좌석수                    -3.1596      0.595     -5.308      0.000      -4.326      -1.993
# 할인금액                   -0.1969      0.008    -24.539      0.000      -0.213      -0.181
# 성별                    361.5864    118.231      3.058      0.002     129.847     593.326
# 연령                     -1.8363      0.139    -13.242      0.000      -2.108      -1.565
# 극장규모                 4521.7307    193.655     23.349      0.000    4142.158    4901.303
# 재관람                  -297.9751    910.706     -0.327      0.744   -2083.005    1487.054
# 조기예매                  -32.8851    164.262     -0.200      0.841    -354.848     289.078
# 공연일시_시간              -192.8363     28.025     -6.881      0.000    -247.767    -137.906
# 공연시작일자_연              372.9856     27.593     13.517      0.000     318.902     427.069
# 공연시작일자_월              -80.5219     30.996     -2.598      0.009    -141.276     -19.768
# 공연시작일자_일              -33.3274      7.997     -4.168      0.000     -49.002     -17.653
# 공연종료일자_연             1.088e+04    606.030     17.955      0.000    9693.378    1.21e+04
# 공연종료일자_월              204.1045     56.932      3.585      0.000      92.515     315.694
# 공연종료일자_일               58.9661     10.726      5.497      0.000      37.942      79.990
# 스타배우                 5031.6383    394.351     12.759      0.000    4258.690    5804.587
# 공연지역명_강원도           -1.529e+06   8.25e+04    -18.547      0.000   -1.69e+06   -1.37e+06
# 공연지역명_경기도           -1.526e+06   8.25e+04    -18.506      0.000   -1.69e+06   -1.36e+06
# 공연지역명_경상도           -1.521e+06   8.25e+04    -18.439      0.000   -1.68e+06   -1.36e+06
# 공연지역명_서울            -1.516e+06   8.25e+04    -18.382      0.000   -1.68e+06   -1.35e+06
# 공연지역명_전라도           -1.519e+06   8.25e+04    -18.418      0.000   -1.68e+06   -1.36e+06
# 공연지역명_제주도           -1.482e+06   8.26e+04    -17.930      0.000   -1.64e+06   -1.32e+06
# 공연지역명_충청도            -1.52e+06   8.25e+04    -18.429      0.000   -1.68e+06   -1.36e+06
# 예매/취소방식명(관리시스템)_모바일 -5.307e+06   2.89e+05    -18.380      0.000   -5.87e+06   -4.74e+06
# 예매/취소방식명(관리시스템)_웹   -5.306e+06   2.89e+05    -18.378      0.000   -5.87e+06   -4.74e+06
# 내한공연 여부_N           -1.061e+07   5.77e+05    -18.379      0.000   -1.17e+07   -9.48e+06
# 오픈런 여부_N            -5.303e+06   2.89e+05    -18.372      0.000   -5.87e+06   -4.74e+06
# 오픈런 여부_Y            -5.309e+06   2.89e+05    -18.387      0.000   -5.88e+06   -4.74e+06
# ==============================================================================
# Omnibus:                    14373.462   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           297649.152
# Skew:                           2.049   Prob(JB):                         0.00
# Kurtosis:                      18.562   Cond. No.                     1.21e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.13e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 재관람, 조기예매 유의 X

# %%
# 뮤지컬
# 연극
# 독립변수와 종속변수 설정
X_mus = df_musical[['좌석수', '할인금액','성별', '연령', '극장규모', '재관람', '조기예매', '공연일시_시간', '공연시작일자_연', '공연시작일자_월', '공연시작일자_일', '공연종료일자_연', '공연종료일자_월', '공연종료일자_일', '스타배우', '공연지역명_강원도', '공연지역명_경기도', '공연지역명_경상도', '공연지역명_서울', '공연지역명_전라도', '공연지역명_제주도', '공연지역명_충청도',
                  '예매/취소방식명(관리시스템)_모바일', '예매/취소방식명(관리시스템)_웹', '내한공연 여부_Y','내한공연 여부_N', '오픈런 여부_N', '오픈런 여부_Y']]

y_mus = df_musical['예매/취소금액']

# Train-Test Split
X_train_m, X_test_m, y_train_m, y_test_m = train_test_split(X_mus, y_mus, test_size=0.2, random_state=42)

# 회귀모델 학습
model = LinearRegression()
model.fit(X_train_m, y_train_m)

# 테스트 데이터로 예측
y_pred_m = model.predict(X_test_m)

# 모델 평가
mse = mean_squared_error(y_test_m, y_pred_m)
r2 = r2_score(y_test_m, y_pred_m)

print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 968227075.0770992
# R-squared: 0.627824349877476

# %%
import numpy as np
import statsmodels.api as sm

# 모든 변수를 float64로 변환
X_train_float = X_train_m.astype(np.float64)
y_train_float = y_train_m.astype(np.float64)

# 상수항 추가 (절편을 포함하기 위해 필요)
X_train_sm = sm.add_constant(X_train_float)

# OLS(Ordinary Least Squares) 모델 적합
model_sm = sm.OLS(y_train_float, X_train_sm).fit()

# 회귀 분석 요약 출력
print(model_sm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                예매/취소금액   R-squared:                       0.628
# Model:                            OLS   Adj. R-squared:                  0.627
# Method:                 Least Squares   F-statistic:                     3383.
# Date:                Mon, 19 Aug 2024   Prob (F-statistic):               0.00
# Time:                        05:57:55   Log-Likelihood:            -5.6690e+05
# No. Observations:               48188   AIC:                         1.134e+06
# Df Residuals:                   48163   BIC:                         1.134e+06
# Df Model:                          24
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const               -4.916e+07   2.53e+06    -19.441      0.000   -5.41e+07   -4.42e+07
# 좌석수                    62.0955      0.689     90.130      0.000      60.745      63.446
# 할인금액                   -0.4412      0.020    -22.613      0.000      -0.479      -0.403
# 성별                   1931.1887    268.687      7.188      0.000    1404.559    2457.818
# 연령                      0.9033      0.358      2.526      0.012       0.202       1.604
# 극장규모                 1.452e+04    447.660     32.432      0.000    1.36e+04    1.54e+04
# 재관람                  4509.1851   2139.301      2.108      0.035     316.128    8702.242
# 조기예매                 4764.5574    301.685     15.793      0.000    4173.251    5355.864
# 공연일시_시간               350.9809     65.312      5.374      0.000     222.968     478.994
# 공연시작일자_연             1.396e+04    883.050     15.804      0.000    1.22e+04    1.57e+04
# 공연시작일자_월            -2432.7662    224.730    -10.825      0.000   -2873.240   -1992.292
# 공연시작일자_일             -337.7596     23.371    -14.452      0.000    -383.568    -291.951
# 공연종료일자_연             5.028e+04   3094.534     16.249      0.000    4.42e+04    5.63e+04
# 공연종료일자_월             3530.0803    290.053     12.170      0.000    2961.573    4098.587
# 공연종료일자_일              526.5380     23.367     22.534      0.000     480.739     572.337
# 스타배우                 2013.4030    411.855      4.889      0.000    1206.161    2820.645
# 공연지역명_강원도           -7.008e+06   3.62e+05    -19.372      0.000   -7.72e+06    -6.3e+06
# 공연지역명_경기도           -7.045e+06   3.62e+05    -19.482      0.000   -7.75e+06   -6.34e+06
# 공연지역명_경상도           -7.039e+06   3.62e+05    -19.465      0.000   -7.75e+06   -6.33e+06
# 공연지역명_서울            -7.023e+06   3.62e+05    -19.406      0.000   -7.73e+06   -6.31e+06
# 공연지역명_전라도            -7.05e+06   3.62e+05    -19.493      0.000   -7.76e+06   -6.34e+06
# 공연지역명_제주도           -6.935e+06   3.59e+05    -19.340      0.000   -7.64e+06   -6.23e+06
# 공연지역명_충청도           -7.061e+06   3.62e+05    -19.524      0.000   -7.77e+06   -6.35e+06
# 예매/취소방식명(관리시스템)_모바일 -2.458e+07   1.26e+06    -19.441      0.000   -2.71e+07   -2.21e+07
# 예매/취소방식명(관리시스템)_웹   -2.458e+07   1.26e+06    -19.442      0.000   -2.71e+07   -2.21e+07
# 내한공연 여부_Y           -2.453e+07   1.26e+06    -19.403      0.000    -2.7e+07   -2.21e+07
# 내한공연 여부_N           -2.463e+07   1.26e+06    -19.480      0.000   -2.71e+07   -2.22e+07
# 오픈런 여부_N            -2.458e+07   1.26e+06    -19.443      0.000   -2.71e+07   -2.21e+07
# 오픈런 여부_Y            -2.458e+07   1.26e+06    -19.440      0.000   -2.71e+07   -2.21e+07
# ==============================================================================
# Omnibus:                     2205.432   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2542.365
# Skew:                          -0.533   Prob(JB):                         0.00
# Kurtosis:                       3.361   Cond. No.                     1.50e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.74e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 전부 유의

# %% [markdown]
# # 회귀분석 결론
#
# - 연극에서 조기예매가 유의하지 않게 검출된다.

# %% [markdown]
# # 재관람 여부 로지스틱 회귀분석

# %% [markdown]
# 시도해봤는데 재관람 데이터가 워낙 불균형해서 성능이 너무 안좋아서 안하는 게 나을듯함

# %% [markdown]
# # 티켓 가격 예측 랜덤포레스트

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# 연극
# 독립변수와 종속변수 설정
X_play = df_play[['좌석수', '할인금액','성별', '연령', '극장규모', '재관람', '조기예매', '공연일시_시간', '공연시작일자_연', '공연시작일자_월', '공연시작일자_일', '공연종료일자_연', '공연종료일자_월', '공연종료일자_일', '스타배우', '공연지역명_강원도', '공연지역명_경기도', '공연지역명_경상도', '공연지역명_서울', '공연지역명_전라도', '공연지역명_제주도', '공연지역명_충청도',
                  '예매/취소방식명(관리시스템)_모바일', '예매/취소방식명(관리시스템)_웹', '내한공연 여부_N', '오픈런 여부_N', '오픈런 여부_Y']]

y_play = df_play['장당금액']

# 랜덤 포레스트 회귀 모델 학습
rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X_train_p, y_train_p)

# 테스트 데이터 예측
y_pred_p = rf_model.predict(X_test_p)

# 모델 성능 평가
mse = mean_squared_error(y_test_p, y_pred_p)
r2 = r2_score(y_test_p, y_pred_p)

print("Mean Squared Error:", mse)
print("R2 Score:", r2)

# 피쳐 중요도 추출
feature_importances = rf_model.feature_importances_

# 피쳐 중요도를 시각화하기 위해 정렬
features = X_play.columns
importance_df = pd.DataFrame({'Feature': features, 'Importance': feature_importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# 피쳐 중요도 시각화
plt.figure(figsize=(12, 8))
plt.barh(importance_df['Feature'], importance_df['Importance'], color='skyblue')
plt.xlabel('Feature Importance')
plt.title('Feature Importance from Random Forest')
plt.gca().invert_yaxis()
plt.show()
# Out:
# Mean Squared Error: 15761671.269478654
# R2 Score: 0.8901855284686618

# %%
# 뮤지컬
# 독립변수와 종속변수 설정
X_mus = df_musical[['좌석수', '할인금액','성별', '연령', '극장규모', '재관람', '조기예매', '공연일시_시간', '공연시작일자_연', '공연시작일자_월', '공연시작일자_일', '공연종료일자_연', '공연종료일자_월', '공연종료일자_일', '스타배우', '공연지역명_강원도', '공연지역명_경기도', '공연지역명_경상도', '공연지역명_서울', '공연지역명_전라도', '공연지역명_제주도', '공연지역명_충청도',
                  '예매/취소방식명(관리시스템)_모바일', '예매/취소방식명(관리시스템)_웹', '내한공연 여부_Y','내한공연 여부_N', '오픈런 여부_N', '오픈런 여부_Y']]

y_mus = df_musical['장당금액']

# Train-Test Split
X_train_m, X_test_m, y_train_m, y_test_m = train_test_split(X_mus, y_mus, test_size=0.2, random_state=42)


# 랜덤 포레스트 회귀 모델 학습
rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X_train_m, y_train_m)

# 테스트 데이터 예측
y_pred_m = rf_model.predict(X_test_m)

# 모델 성능 평가
mse = mean_squared_error(y_test_m, y_pred_m)
r2 = r2_score(y_test_m, y_pred_m)

print("Mean Squared Error:", mse)
print("R2 Score:", r2)

# 피쳐 중요도 추출
feature_importances = rf_model.feature_importances_

# 피쳐 중요도를 시각화하기 위해 정렬
features = X_mus.columns
importance_df = pd.DataFrame({'Feature': features, 'Importance': feature_importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# 피쳐 중요도 시각화
plt.figure(figsize=(12, 8))
plt.barh(importance_df['Feature'], importance_df['Importance'], color='skyblue')
plt.xlabel('Feature Importance')
plt.title('Feature Importance from Random Forest')
plt.gca().invert_yaxis()
plt.show()
# Out:
# Mean Squared Error: 519878101.6150617
# R2 Score: 0.782006966270646

# %%
# 연극
# 독립변수와 종속변수 설정
X_play = df_play[['좌석수', '할인금액','성별', '연령', '극장규모', '재관람', '조기예매', '공연일시_시간', '공연시작일자_연', '공연시작일자_월', '공연시작일자_일', '공연종료일자_연', '공연종료일자_월', '공연종료일자_일', '스타배우', '공연지역명_강원도', '공연지역명_경기도', '공연지역명_경상도', '공연지역명_서울', '공연지역명_전라도', '공연지역명_제주도', '공연지역명_충청도',
                  '예매/취소방식명(관리시스템)_모바일', '예매/취소방식명(관리시스템)_웹', '내한공연 여부_N', '오픈런 여부_N', '오픈런 여부_Y']]

y_play = df_play['예매/취소금액']

# 랜덤 포레스트 회귀 모델 학습
rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X_train_p, y_train_p)

# 테스트 데이터 예측
y_pred_p = rf_model.predict(X_test_p)

# 모델 성능 평가
mse = mean_squared_error(y_test_p, y_pred_p)
r2 = r2_score(y_test_p, y_pred_p)

print("Mean Squared Error:", mse)
print("R2 Score:", r2)

# 피쳐 중요도 추출
feature_importances = rf_model.feature_importances_

# 피쳐 중요도를 시각화하기 위해 정렬
features = X_play.columns
importance_df = pd.DataFrame({'Feature': features, 'Importance': feature_importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# 피쳐 중요도 시각화
plt.figure(figsize=(12, 8))
plt.barh(importance_df['Feature'], importance_df['Importance'], color='skyblue')
plt.xlabel('Feature Importance')
plt.title('Feature Importance from Random Forest')
plt.gca().invert_yaxis()
plt.show()
# Out:
# Mean Squared Error: 15761671.269478654
# R2 Score: 0.8901855284686618

# %%
# 뮤지컬
# 독립변수와 종속변수 설정
X_mus = df_musical[['좌석수', '할인금액','성별', '연령', '극장규모', '재관람', '조기예매', '공연일시_시간', '공연시작일자_연', '공연시작일자_월', '공연시작일자_일', '공연종료일자_연', '공연종료일자_월', '공연종료일자_일', '스타배우', '공연지역명_강원도', '공연지역명_경기도', '공연지역명_경상도', '공연지역명_서울', '공연지역명_전라도', '공연지역명_제주도', '공연지역명_충청도',
                  '예매/취소방식명(관리시스템)_모바일', '예매/취소방식명(관리시스템)_웹', '내한공연 여부_Y','내한공연 여부_N', '오픈런 여부_N', '오픈런 여부_Y']]

y_mus = df_musical['예매/취소금액']

# Train-Test Split
X_train_m, X_test_m, y_train_m, y_test_m = train_test_split(X_mus, y_mus, test_size=0.2, random_state=42)


# 랜덤 포레스트 회귀 모델 학습
rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X_train_m, y_train_m)

# 테스트 데이터 예측
y_pred_m = rf_model.predict(X_test_m)

# 모델 성능 평가
mse = mean_squared_error(y_test_m, y_pred_m)
r2 = r2_score(y_test_m, y_pred_m)

print("Mean Squared Error:", mse)
print("R2 Score:", r2)

# 피쳐 중요도 추출
feature_importances = rf_model.feature_importances_

# 피쳐 중요도를 시각화하기 위해 정렬
features = X_mus.columns
importance_df = pd.DataFrame({'Feature': features, 'Importance': feature_importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# 피쳐 중요도 시각화
plt.figure(figsize=(12, 8))
plt.barh(importance_df['Feature'], importance_df['Importance'], color='skyblue')
plt.xlabel('Feature Importance')
plt.title('Feature Importance from Random Forest')
plt.gca().invert_yaxis()
plt.show()
# Out:
# Mean Squared Error: 519807251.8336091
# R2 Score: 0.8001919106897822

# %% [markdown]
# # 결론
#
# 스타배우의 중요도가 둘 다 그닥.
