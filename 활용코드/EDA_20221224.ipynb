# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 3s (3,417 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 123594 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %% [markdown]
# 런타임 재시작

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'NanumGothic'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 임의의 데이터 생성
x = np.linspace(0, 10, 100)
y = np.sin(x)

# 간단한 시각화
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='사인 곡선', color='blue')
plt.title('한글 폰트 확인', fontsize=16)
plt.xlabel('X축', fontsize=14)
plt.ylabel('Y축', fontsize=14)
plt.legend()
plt.grid()

# 결과 출력
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("/content/drive/MyDrive/KOPIS공모전/데이터/22년/(데이터)_19년 하반기~ _22년 하반기 공모전 raw데이터_2022_12_24_741,469.xlsx")
df.head()
# Out:
#     전송사업자코드 전송사업자명    공연시설코드       시설특성    개관연도                            주소  \
# 0  SE000201   인터파크  FC222069  민간(대학로 외)  2012.0  서울특별시 마포구 양화로11길 60 (서교동) 2층
# 1  SE000201   인터파크  FC222069  민간(대학로 외)  2012.0  서울특별시 마포구 양화로11길 60 (서교동) 2층
# 2  SE000201   인터파크  FC222069  민간(대학로 외)  2012.0  서울특별시 마포구 양화로11길 60 (서교동) 2층
# 3  SE000201   인터파크  FC222069  민간(대학로 외)  2012.0  서울특별시 마포구 양화로11길 60 (서교동) 2층
# 4  SE000201   인터파크  FC222069  민간(대학로 외)  2012.0  서울특별시 마포구 양화로11길 60 (서교동) 2층
#
#   편의시설_레스토랑 여부 편의시설_카페 여부 편의시설_편의점 여부 편의시설_놀이방 여부  ... 아동공연 여부 축제 여부 내한공연 여부  \
# 0            N          Y           N           N  ...       Y     N       N
# 1            N          Y           N           N  ...       Y     N       N
# 2            N          Y           N           N  ...       Y     N       N
# 3            N          Y           N           N  ...       Y     N       N
# 4            N          Y           N           N  ...       Y     N       N
#
#   오픈런 여부               판매시작일시               판매종료일시       좌석등급 단독판매여부  판매좌석수  \
# 0      Y  2022/10/21 11:00:00  9999/12/31 12:00:00  전석(50000)      Y   193석
# 1      Y  2022/10/21 11:00:00  9999/12/31 12:00:00  전석(50000)      Y   193석
# 2      Y  2022/10/21 11:00:00  9999/12/31 12:00:00  전석(50000)      Y   193석
# 3      Y  2022/10/21 11:00:00  9999/12/31 12:00:00  전석(50000)      Y   193석
# 4      Y  2022/10/21 11:00:00  9999/12/31 12:00:00  전석(50000)      Y   193석
#
#                                             판매페이지URL
# 0  http://ticket.interpark.com/Ticket/Goods/Goods...
# 1  http://ticket.interpark.com/Ticket/Goods/Goods...
# 2  http://ticket.interpark.com/Ticket/Goods/Goods...
# 3  http://ticket.interpark.com/Ticket/Goods/Goods...
# 4  http://ticket.interpark.com/Ticket/Goods/Goods...
#
# [5 rows x 68 columns]

# %%
df.columns
# Out:
# Index(['전송사업자코드', '전송사업자명', '공연시설코드', '시설특성', '개관연도', '주소', '편의시설_레스토랑 여부',
#        '편의시설_카페 여부', '편의시설_편의점 여부', '편의시설_놀이방 여부', '편의시설_수유실 여부',
#        '장애인시설_주차장 여부', '장애인시설_화장실 여부', '장애인시설_경사로 여부', '장애인시설_전용엘리베이터 여부',
#        '주차시설_자체 여부', '주차시설_공영 여부', '공연장코드', '좌석수', '장애인석', '무대시설_오케스트라피트 여부',
#        '무대시설_연습실 여부', '무대시설_분장실 여부', '무대시설_무대넓이', '공연코드', '공연회차', '공연일시',
#        '입장권고유번호', '예매/취소일시', '예매/취소구분', '예매/취소매수', '예매/취소금액', '예매/취소방식코드',
#        '예매/취소방식명(관리시스템)', '예매/취소방식명(전송처)', '결제수단코드', '결제수단명(관리시스템)',
#        '결제수단명(전송처)', '할인금액', '할인종류코드', '할인종류명(관리시스템)', '할인종류명(전송처)', '장당금액',
#        '성별', '연령', '공연시작일자', '공연종료일자', '소요시간', '장르명', '세부장르명', '공연지역명',
#        '출연진내용', '제작진내용', '기획제작사명', '원작자명', '극작가명', '수상실적', '관람연령', '아동공연 여부',
#        '축제 여부', '내한공연 여부', '오픈런 여부', '판매시작일시', '판매종료일시', '좌석등급', '단독판매여부',
#        '판매좌석수', '판매페이지URL'],
#       dtype='object')

# %%
columns_to_select = ['좌석수', '공연코드', '공연일시', '예매/취소일시', '예매/취소구분',
                     '예매/취소매수', '예매/취소금액', '예매/취소방식명(관리시스템)',
                     '할인금액', '할인종류명(전송처)', '장당금액', '성별', '연령',
                     '공연시작일자', '공연종료일자', '장르명', '공연지역명',
                     '출연진내용', '아동공연 여부', '내한공연 여부',
                     '오픈런 여부', '판매시작일시', '판매종료일시', '좌석등급']

# DataFrame에서 선택한 열만 포함
df = df.loc[:, columns_to_select]
df.columns
# Out:
# Index(['좌석수', '공연코드', '공연일시', '예매/취소일시', '예매/취소구분', '예매/취소매수', '예매/취소금액',
#        '예매/취소방식명(관리시스템)', '할인금액', '할인종류명(전송처)', '장당금액', '성별', '연령', '공연시작일자',
#        '공연종료일자', '장르명', '공연지역명', '출연진내용', '아동공연 여부', '내한공연 여부', '오픈런 여부',
#        '판매시작일시', '판매종료일시', '좌석등급'],
#       dtype='object')

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# ##예매취소 데이터 제거

# %%
df['예매/취소구분'].value_counts()
# Out:
# 예매/취소구분
# 1    529939
# 2    211530
# Name: count, dtype: int64

# %%
df=df[df['예매/취소구분']==1]
df['예매/취소구분'].value_counts()
# Out:
# 예매/취소구분
# 1    529939
# Name: count, dtype: int64

# %% [markdown]
# ## 연령

# %%
df['연령'].describe()
# Out:
# count    529939.000000
# mean       1605.638192
# std         782.291348
# min           0.000000
# 25%        1972.000000
# 50%        1985.000000
# 75%        1992.000000
# max        2095.000000
# Name: 연령, dtype: float64

# %%
df['연령']=2024-df['연령']+1
df['연령'].describe()
# Out:
# count    529939.000000
# mean        419.361808
# std         782.291348
# min         -70.000000
# 25%          33.000000
# 50%          40.000000
# 75%          53.000000
# max        2025.000000
# Name: 연령, dtype: float64

# %%
df['연령'].head(10)
# Out:
# 0    40
# 1    40
# 2    48
# 3    48
# 4    48
# 5    48
# 6    41
# 7    41
# 8    41
# 9    43
# Name: 연령, dtype: int64

# %% [markdown]
# 0에서 100 사이가 아닌건 모두 이상치이지만, 일단은 드롭하지 않는다.

# %% [markdown]
# ## 아동공연

# %%
df['아동공연 여부'].value_counts()
# Out:
# 아동공연 여부
# N    436386
# Y     93553
# Name: count, dtype: int64

# %%
df=df[df['아동공연 여부']=='N']
df['아동공연 여부'].value_counts()
# Out:
# 아동공연 여부
# N    436386
# Name: count, dtype: int64

# %% [markdown]
# ## 모바일, 웹만 남기기

# %%
df['예매/취소방식명(관리시스템)'].value_counts()
# Out:
# 예매/취소방식명(관리시스템)
# 모바일    202191
# 웹      167332
# 현장      44833
# 기타      19212
# 전화       2818
# Name: count, dtype: int64

# %%
df=df[(df['예매/취소방식명(관리시스템)']=='웹')|
      (df['예매/취소방식명(관리시스템)']=='모바일')]

df['예매/취소방식명(관리시스템)'].value_counts()
# Out:
# 예매/취소방식명(관리시스템)
# 모바일    202191
# 웹      167332
# Name: count, dtype: int64

# %% [markdown]
# ## 극장 규모 칼럼

# %% [markdown]
# 연극/ 뮤지컬 별로 다르다.
#
# <연극>
#
# 소극장 : 100석 미만
# 중극장 : 100- 300
# 대극장 : 300초과
# <뮤지컬>
#
# 소극장 : 300석 이하
# 중극장 : 300 - 1000
# 대극장 : 1000석 이상
# -> 소극장 = 0,중극장 =1, 대극장=2

# %%
# 연극과 뮤지컬 데이터만 필터링
df_filtered = df[(df['장르명'] == '연극') | (df['장르명'] == '뮤지컬')]

# 극장 크기 분류 함수 정의
def categorize_theater(row):
    if row['장르명'] == '연극':
        if row['좌석수'] < 100:
            return 0  # 소극장
        elif 100 <= row['좌석수'] < 300:
            return 1  # 중극장
        else:
            return 2  # 대극장
    elif row['장르명'] == '뮤지컬':
        if row['좌석수'] <= 300:
            return 0  # 소극장
        elif 300 < row['좌석수'] < 1000:
            return 1  # 중극장
        else:
            return 2  # 대극장

# 분류 기준 적용
df_filtered['극장규모'] = df_filtered.apply(categorize_theater, axis=1)
df_filtered['극장규모'].value_counts()
# Out:
# <ipython-input-19-a25025beb368>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['극장규모'] = df_filtered.apply(categorize_theater, axis=1)
# 극장규모
# 2    68198
# 1    38017
# 0     9058
# Name: count, dtype: int64

# %%
df_filtered.groupby('장르명')['극장규모'].value_counts()
# Out:
# 장르명  극장규모
# 뮤지컬  2       54123
#      1       15418
#      0        5163
# 연극   1       22599
#      2       14075
#      0        3895
# Name: count, dtype: int64

# %%
df=df_filtered
df.groupby('장르명')['극장규모'].value_counts()
# Out:
# 장르명  극장규모
# 뮤지컬  2       54123
#      1       15418
#      0        5163
# 연극   1       22599
#      2       14075
#      0        3895
# Name: count, dtype: int64

# %% [markdown]
# ## 재관람 칼럼

# %% [markdown]
# 재관람 = 1, 아니면 0

# %%
df['할인종류명(전송처)'].unique()
# Out:
# array(['기타', '공연사 할인', nan, 'N', '크리스마스 조기예매', '크리스마스 할인', '임직원할인',
#        '판매자 할인쿠폰', '뭉쳐라 4인 할인', '조기예매할인', '청소년할인(본인만)', '드림씨어터 선예매',
#        '조기예매 할인', '청소년 할인', '장애인할인(4-6급)', '회원할인', '국가 유공자할인',
#        '22-23 프리패키지Ⅰ - S 33,000원', '22-23 프리패키지Ⅰ - R 55,000원',
#        '국가유공자유족 50%', '조기예매 할인 20%', '엔톡(NTOK)회원 20%', '개막 기념 할인 15,000원',
#        '경로 50%', '서울시 중구민 할인', '국가 유공자 할인', '오프닝 위크 티켓소지자 할인', '1차 조기예매',
#        '청소년(04년~15년출생자,본인만)', '장애인(경증,4-6급,본인만)', '재관람(영웅유료티켓소지자,1인1매)',
#        '조기예매', 'BC카드', '그랜드십일절 할인', '다중할인', '신용카드사', '장애인(1~3급 중증/동반1인)',
#        '학생할인(초중고 본인)', '임직원할인_BC카드 결제시', '재관람 할인', '장애인(1~3급) 할인',
#        '초중고생(A석에한함/본인만)', 'BC 카드회원', '연말준비 할인', '특별할인', '[투어컬처위크] 할인쿠폰',
#        '[투어컬처위크] 스페셜쿠폰(12/14)', '[비씨카드] 할인쿠폰', '직장인할인(명함,사원증지참/1인2매)',
#        '커플할인', '만원愛', '[투어컬처프로] 할인쿠폰', 'BC카드할인', '3차조기예매할인 (BC카드 결제 시)',
#        'BC 카드 할인', '주말 및 공휴일할인', '친한친구(유료회원)40%', '국립극단연극인회원50%_본인만',
#        '푸른티켓_본인만', '대학생및청소년40%', '스카팽_내부관계자50%', '예술인패스소지자30%',
#        '재관람30%_유료실물티켓소지시', '삼삼오오30%', '문화릴레이티켓20%', '경로(만65세이상)50%',
#        '장애인50%', '문화누리카드소지자50%', '신규회원 20%할인쿠폰', '2023년수능생40%',
#        '[KB국민카드] 할인쿠폰', '[하나카드] 공연/티켓 할인쿠폰', '예술인관계자', '예술인패스카드 45%',
#        '직장인할인 15%', '경로 30%', 'collective iNG 30%', '연극인할인',
#        '[11월문화데이] 연극/대학로, 전시/체험, 키즈 쿠폰', 'TIME SALE', '조기할인', 'COUPON',
#        '프리뷰할인', '50%할인', '권종할인', '크리스마스 특가할인', '크리스마스 특별할인',
#        'R석 크리스마스 특가할인', '크리스마스 사전예매', '[여행페스타] 3만원 할인쿠폰', 'VIP카드회원',
#        '1차 조기예매 할인', '크리스마스 나이트 특별 할인(2인권)', '재관람(1인2매)', '만원의행복',
#        '[하나카드] 할인쿠폰', '국가유공자(본인)', '3차조기예매할인', '3차조기예매할인(BC카드결제시)',
#        '3인 패키지(BC카드 결제시)', '장애인(1~3급) 동반1인', '장애인(4~6급) 할인',
#        '[비씨카드] 공연/티켓 할인쿠폰', '재관람할인(1인1매)', '수험생할인(1인1매)'], dtype=object)

# %%
lst=['엔톡(NTOK)회원','친한친구(유료회원)40%', '국립극단연극인회원50%_본인만',
       '스카팽_내부관계자50%', '예술인패스소지자30%',
       '재관람30%_유료실물티켓소지시', '예술인관계자', '예술인패스카드 45%',
        '연극인할인','재관람(1인2매)','재관람할인(1인1매)']

# '할인종류명(전송처)'이 lst에 있으면 '재관람' 칼럼에 1을, 아니면 0을 부여
df['재관람'] = df['할인종류명(전송처)'].apply(lambda x: 1 if x in lst else 0)

# 결과 확인
df['재관람'].value_counts()
# Out:
# 재관람
# 0    115165
# 1       108
# Name: count, dtype: int64

# %% [markdown]
# ## 조기예매 여부 칼럼

# %% [markdown]
# 1) 데이터 필터링
#
# 2) 새로운 파생변수 조기예매 여부: 조기예매면 1, 아니면 0
#
# abs(예매취소일시 - 판매시작일시) = 10

# %%
df['판매시작일시'].head()
# Out:
# 313    2020/04/04 00:00:00
# 314    2020/04/04 00:00:00
# 315    2020/04/04 00:00:00
# 316    2020/04/04 00:00:00
# 317    2020/04/04 00:00:00
# Name: 판매시작일시, dtype: object

# %%
# 1. 판매시작일시 열이 문자열이 아닌 경우, 문자열로 변환
df['판매시작일시'] = df['판매시작일시'].astype(str)

# 2. 결측치 처리: 판매시작일시가 9999년, 2099년, 2021년인 경우 NaT로 처리
df.loc[df['판매시작일시'].str[:4].isin(['9999', '2099', '2021']), '판매시작일시'] = pd.NaT

# 3. 판매시작일시와 예매/취소일시를 datetime 형식으로 변환
df['판매시작일시'] = pd.to_datetime(df['판매시작일시'], errors='coerce')
df['예매/취소일시'] = pd.to_datetime(df['예매/취소일시'], errors='coerce')

# 4. 조기예매 판정: 예매/취소일시와 판매시작일시의 차이가 10일 이하인 경우 1, 그렇지 않으면 0
df['조기예매'] = (df['예매/취소일시'] - df['판매시작일시']).dt.days <= 10

# True/False 값을 1/0으로 변환
df['조기예매'] = df['조기예매'].astype(int)

# 결과 확인
print(df['조기예매'].value_counts())
# Out:
# 조기예매
# 0    66512
# 1    48761
# Name: count, dtype: int64

# %%
# 데이터 다운로드
df.to_excel("/content/drive/MyDrive/KOPIS공모전/데이터/EDA용 데이터/20221224.xlsx",
            index=False)

# %% [markdown]
# ## 연극/뮤지컬 데이터 분리

# %%
df['장르명'].value_counts()
# Out:
# 장르명
# 뮤지컬    74704
# 연극     40569
# Name: count, dtype: int64

# %%
df_play = df[df['장르명']=='연극']
df_musical= df[df['장르명']=='뮤지컬']

# %% [markdown]
# # EDA_연극

# %% [markdown]
# ### 공연코드

# %%
df_play['공연코드'].value_counts()
# Out:
# 공연코드
# PF424254    1599
# PF422596    1504
# PF343804    1223
# PF394750    1089
# PF352013    1021
#             ...
# PF424236       3
# PF426256       3
# PF425457       2
# PF426766       1
# PF424404       1
# Name: count, Length: 140, dtype: int64

# %% [markdown]
# ### 공연일시에 따른 가격

# %%
df_play['공연일시']=pd.to_datetime(df_play['공연일시'])

# 시각화: 공연일시별 평균 장당금액 변화
mean_price = df_play.groupby('공연일시')['장당금액'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(x='공연일시', y='장당금액', data=mean_price, marker='o')
plt.title('Ticket Price by Performance Time')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-30-8228dca8b27c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_play['공연일시']=pd.to_datetime(df_play['공연일시'])

# %% [markdown]
# ### 예매/취소매수

# %%
df_play['예매/취소매수'].value_counts()
# Out:
# 예매/취소매수
# 1    40569
# Name: count, dtype: int64

# %% [markdown]
# ### 예매/취소 금액

# %%
df_play['예매/취소금액'].value_counts()
# Out:
# 예매/취소금액
# 25000    5058
# 35000    4575
# 30000    3918
# 28000    3130
# 20000    1971
#          ...
# 52500       1
# 31566       1
# 12720       1
# 29010       1
# 15430       1
# Name: count, Length: 201, dtype: int64

# %%
df_play['예매/취소금액'].value_counts().sort_index(ascending=False)
# Out:
# 예매/취소금액
# 131600     23
# 120000      5
# 111600      8
# 101700      9
# 101600      8
#          ...
# 8900        4
# 8000       31
# 7000        2
# 5000       37
# 0         333
# Name: count, Length: 201, dtype: int64

# %%
# 예매취소금액 분포
# 예매취소금액이 0인 것은 결측치로 처리하고 제거

df_play_price=df_play[df_play['예매/취소금액']!=0]

# 시각화: 금액 분포 박스 플롯
plt.figure(figsize=(8, 6))
sns.boxplot(y='예매/취소금액', data=df_play_price, showfliers=False)
plt.show()

# 시각화: 금액 분포 히스토그램
plt.figure(figsize=(8, 6))
sns.histplot(df_play_price['예매/취소금액'], kde=True)
plt.show()

# %%
# 시각화: 공연일시별 평균 예매금액 변화
mean_price = df_play_price.groupby('공연일시')['예매/취소금액'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(x='공연일시', y='예매/취소금액', data=mean_price, marker='o')
plt.title('Ticket Price by Performance Time')
plt.xticks(rotation=45)
plt.show()

# %%
# 재관람과 비재관람 데이터의 예매/취소 금액 차이

# 박스 플롯 시각화: 재관람 여부에 따른 예매/취소금액 비교
plt.figure(figsize=(10, 6))
sns.boxplot(x='재관람', y='예매/취소금액', data=df_play)
plt.title('Comparison of price by reviewing')
plt.xlabel('Review (0: non, 1: re)')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ### 예매/취소방식명

# %%
df_play['예매/취소방식명(관리시스템)'].value_counts()
# Out:
# 예매/취소방식명(관리시스템)
# 모바일    29282
# 웹      11287
# Name: count, dtype: int64

# %%
# 장당금액 웹 vs 모바일
plt.figure(figsize=(10, 6))
sns.boxplot(x='예매/취소방식명(관리시스템)', y='장당금액', data=df_play)
plt.xlabel('Web vs Mobile')
plt.ylabel('A ticket Price')
plt.show()

# %%
# 할인금액 웹 vs 모바일
# 시각화: 웹 vs 모바일 장당금액 비교 (박스 플롯)
plt.figure(figsize=(10, 6))
sns.boxplot(x='예매/취소방식명(관리시스템)', y='할인금액', data=df_play)
plt.xlabel('Web vs Mobile')
plt.ylabel('Price')
plt.show()

# %%
# 할인금액의 분포를 히스토그램으로 시각화 (웹 vs 모바일)
plt.figure(figsize=(10, 6))
sns.histplot(data=df_play, x='할인금액', hue='예매/취소방식명(관리시스템)', kde=True, multiple='stack')
plt.title('Discount Distn: Web vs Mobile')
plt.xlabel('Discount')
plt.ylabel('Freq')
plt.show()

# %%
# 구매처 별 재관람 건수 시각화
revisit_ratio = df_play.groupby('예매/취소방식명(관리시스템)')['재관람'].sum().reset_index()

# 바 그래프 시각화
plt.figure(figsize=(8, 6))
sns.barplot(x='예매/취소방식명(관리시스템)', y='재관람', data=revisit_ratio)
plt.title('Review Events by Web vs Mobile')
plt.xlabel('Web vs Mobile')
plt.ylabel('Review')
plt.show()

# %%
# 예매방식명별로 재관람 비율 계산
# 재관람의 비율은 '재관람' 값이 1인 경우의 평균으로 계산할 수 있습니다.
revisit_ratio = df_play.groupby('예매/취소방식명(관리시스템)')['재관람'].mean().reset_index()

# 바 그래프 시각화
plt.figure(figsize=(8, 6))
sns.barplot(x='예매/취소방식명(관리시스템)', y='재관람', data=revisit_ratio)
plt.title('웹 vs 모바일 재관람 비율 비교')
plt.xlabel('예매 방식')
plt.ylabel('재관람 비율')
plt.ylim(0, 0.1)
plt.show()

# %% [markdown]
# ### 성별

# %% [markdown]
# 1: 남, 2: 여, 0: 알수없음

# %%
df_play['성별'].value_counts()
# Out:
# 성별
# 2    20346
# 1    14547
# 0     5676
# Name: count, dtype: int64

# %%
# 성별 웹 vs 모바일

# 성별 및 예매/취소방식명(관리시스템)별 빈도 계산
gender_distribution = df_play.groupby(['예매/취소방식명(관리시스템)', '성별']).size().reset_index(name='count')

# 시각화: 웹 vs 모바일 성별 분포 바 그래프
plt.figure(figsize=(10, 6))
sns.barplot(x='예매/취소방식명(관리시스템)', y='count', hue='성별', data=gender_distribution)
plt.title('Gender Distribution: Web vs Mobile')
plt.xlabel('Web vs Mobile')
plt.ylabel('Gender')
plt.legend(title='gender', labels=['0','1', '2'])  # 성별에 맞는 레이블 설정
plt.show()

# %%
# 성별 별 예매금액의 차이

# 1. 성별 값이 0인 데이터를 제거 (0은 결측치로 간주)
df_filtered = df_play[df_play['성별'] != 0]

plt.figure(figsize=(10, 6))
sns.violinplot(x='성별', y='예매/취소금액', data=df_filtered)
plt.title('Price Comparison by Gender (Violin Plot)')
plt.xlabel('Gender (1: Men, 2: Women)')
plt.ylabel('Prices')
plt.xticks(ticks=[0, 1], labels=['Men', 'Women'])  # 성별 레이블 설정
plt.show()

# %%
# 성별 별 장당금액의 차이
# 1. 성별 값이 0인 데이터를 제거 (0은 결측치로 간주)
df_filtered = df_play[df_play['성별'] != 0]

plt.figure(figsize=(10, 6))
sns.violinplot(x='성별', y='장당금액', data=df_filtered)
plt.title('Ticket Price Comparison by Gender (Violin Plot)')
plt.xlabel('Gender (1: Men, 2: Women)')
plt.ylabel('Prices')
plt.xticks(ticks=[0, 1], labels=['Men', 'Women'])  # 성별 레이블 설정
plt.show()

# %%
# 성별 별 극장 규모의 차이

df_filtered = df_play[df_play['성별'] != 0]

# 2. 성별별 극장 규모 분포를 시각화 (countplot 사용)
plt.figure(figsize=(10, 6))
sns.countplot(x='극장규모', hue='성별', data=df_filtered)
plt.title('Theatre Scale by Gender')
plt.xlabel('Theatre scale (0: Small, 1: Medium, 2: Large)')
plt.ylabel('Freq')
plt.xticks(ticks=[0, 1, 2], labels=['Small', 'Medium', 'Large'])
plt.legend(title='gender', labels=['Men', 'Women'])
plt.show()

# %%
# 성별 별 재관람율의 차이
# 1. 성별 값이 0인 데이터를 제거 (0은 결측치로 간주)
df_filtered = df_play[df_play['성별'] != 0]

# 2. 성별별 재관람율 계산
total_counts_by_gender = df_filtered.groupby('성별')['재관람'].count().reset_index(name='총예매수')
revisit_counts_by_gender = df_filtered.groupby('성별')['재관람'].sum().reset_index(name='재관람수')

# 3. 재관람율 계산 (재관람수 / 총예매수)
revisit_ratio_by_gender = pd.merge(revisit_counts_by_gender, total_counts_by_gender, on='성별')
revisit_ratio_by_gender['재관람율'] = revisit_ratio_by_gender['재관람수'] / revisit_ratio_by_gender['총예매수']

# 4. 바 그래프 시각화
plt.figure(figsize=(8, 6))
plt.bar(revisit_ratio_by_gender['성별'].map({1: 'Men', 2: 'Women'}), revisit_ratio_by_gender['재관람율'])
plt.title('Review Proportion Comparison by Gender')
plt.xlabel('gender')
plt.ylabel('Review')
plt.ylim(0, 0.1)  # 비율이므로 y축 범위를 0에서 1로 설정

# 그래프 표시
plt.show()

# %% [markdown]
# ### 연령

# %%
# 1. 연령이 (0, 100) 사이가 아닌건 이상치로 처리하고 제거
df_filtered = df_play[(df_play['연령'] >= 0) & (df_play['연령'] < 100)]

# 2. 연령 분포 시각화 (히스토그램)
plt.figure(figsize=(10, 6))
sns.histplot(df_filtered['연령'], bins=30, kde=True)
plt.title('Age Distn')
plt.xlabel('Age')
plt.ylabel('Freq')
plt.show()

# %%
# 성별 별 연령분포
df_filtered = df_play[df_play['성별'] != 0]

# 2. 연령 분포 시각화 (히스토그램)
plt.figure(figsize=(10, 6))
sns.histplot(data=df_filtered, x='연령', hue='성별', bins=30, kde=True, multiple='stack')
plt.title('Age Distn by Gender')
plt.xlabel('Age')
plt.ylabel('Freq')
plt.legend(title='gender', labels=['M', 'W'])
plt.show()

# %%
# 재관람 여부 별 연령 분포의 차이
df_filtered= df_play[(df_play['연령'] >= 0) & (df_play['연령'] < 100)]
plt.figure(figsize=(10, 6))
sns.histplot(data=df_filtered, x='연령', hue='재관람', bins=30, kde=True, multiple='stack')
plt.title('Age distn by reviewing')
plt.xlabel('Age')
plt.ylabel('Freq')
plt.legend(title='Review', labels=['re', 'non'])
plt.show()

# %%
# 1. 재관람 여부 별 연령 분포 시각화 (박스 플롯)
plt.figure(figsize=(10, 6))
sns.boxplot(x='재관람', y='연령', data=df_filtered)
plt.xlabel('Reviewing (0: non, 1: re)')
plt.ylabel('Age')
plt.xticks(ticks=[0, 1], labels=['non', 're'])
plt.show()

# %%
# 연령 별 극장 규모 차이

# 1. 연령 별 극장 규모 시각화 (박스 플롯)
plt.figure(figsize=(10, 6))
sns.boxplot(x='극장규모', y='연령', data=df_filtered)
plt.title('연령 별 극장 규모 차이 (박스 플롯)')
plt.xlabel('극장 규모 (0: 소극장, 1: 중극장, 2: 대극장)')
plt.ylabel('연령')
plt.xticks(ticks=[0, 1, 2], labels=['소극장', '중극장', '대극장'])
plt.show()

# 2. 연령 별 극장 규모 시각화 (바이올린 플롯)
plt.figure(figsize=(10, 6))
sns.violinplot(x='극장규모', y='연령', data=df_filtered)
plt.title('연령 별 극장 규모 차이 (바이올린 플롯)')
plt.xlabel('극장 규모 (0: 소극장, 1: 중극장, 2: 대극장)')
plt.ylabel('연령')
plt.xticks(ticks=[0, 1, 2], labels=['소극장', '중극장', '대극장'])
plt.show()

# %% [markdown]
# ### 공연지역명

# %%
df_play['공연지역명'].value_counts()
# Out:
# 공연지역명
# 서울     24359
# 경상도     6176
# 전라도     4482
# 충청도     2945
# 경기도     1876
# 제주도      389
# 강원도      342
# Name: count, dtype: int64

# %%
# 공연지역명 별 극장 규모 조회
df_play.groupby('공연지역명')['극장규모'].value_counts()
# Out:
# 공연지역명  극장규모
# 강원도    2         333
#        1           9
# 경기도    2        1504
#        1         326
#        0          46
# 경상도    1        3887
#        2        1707
#        0         582
# 서울     1       15595
#        2        6378
#        0        2386
# 전라도    2        3266
#        1        1167
#        0          49
# 제주도    0         389
# 충청도    1        1615
#        2         887
#        0         443
# Name: count, dtype: int64

# %%
# 공연 지역명 별 장당 가격 비교
# 공연지역명 별 극장 규모 조회
df_play.groupby('공연지역명')['장당금액'].mean()
# Out:
# 공연지역명
# 강원도      456.140351
# 경기도    64402.452026
# 경상도    28268.021373
# 서울     37129.373127
# 전라도    30701.383311
# 제주도    50245.501285
# 충청도    27612.393888
# Name: 장당금액, dtype: float64

# %%
# 공연 지역 별 재관람율 비교
df_play.groupby('공연지역명')['재관람'].mean()
# Out:
# 공연지역명
# 강원도    0.000000
# 경기도    0.000000
# 경상도    0.000000
# 서울     0.004228
# 전라도    0.000000
# 제주도    0.000000
# 충청도    0.000000
# Name: 재관람, dtype: float64

# %%
# 공연 지역 별 재관람율 비교
df_play.groupby('공연지역명')['재관람'].sum()
# Out:
# 공연지역명
# 강원도      0
# 경기도      0
# 경상도      0
# 서울     103
# 전라도      0
# 제주도      0
# 충청도      0
# Name: 재관람, dtype: int64

# %% [markdown]
# ### 내한공연 여부

# %%
df_play['내한공연 여부'].value_counts()
# Out:
# 내한공연 여부
# N    40569
# Name: count, dtype: int64

# %% [markdown]
# ### 오픈런 여부

# %%
df_play['오픈런 여부'].value_counts()
# Out:
# 오픈런 여부
# N    24698
# Y    15871
# Name: count, dtype: int64

# %%
# 오픈런 여부 별 장당 금액 비교
df_play.groupby('오픈런 여부')['장당금액'].mean()
# Out:
# 오픈런 여부
# N    38899.226658
# Y    30100.636381
# Name: 장당금액, dtype: float64

# %%
# 오픈런 여부 별 박스플롯
sns.boxplot(x='오픈런 여부', y='장당금액', data=df_play)
plt.title('Prices of Open Run')
plt.xlabel('Open run O X')
plt.ylabel('Prices')
plt.show()

# %%
# 오픈런 여부 별 극장규모 비교
df_play.groupby('오픈런 여부')['극장규모'].value_counts()
# Out:
# 오픈런 여부  극장규모
# N       2       13726
#         1        8942
#         0        2030
# Y       1       13657
#         0        1865
#         2         349
# Name: count, dtype: int64

# %%
# 오픈런 여부 별 재관람율 비교
df_play.groupby('오픈런 여부')['재관람'].mean()
# Out:
# 오픈런 여부
# N    0.00417
# Y    0.00000
# Name: 재관람, dtype: float64

# %%
df_play.groupby('오픈런 여부')['재관람'].sum()
# Out:
# 오픈런 여부
# N    103
# Y      0
# Name: 재관람, dtype: int64

# %% [markdown]
# ### 조기예매

# %%
# 조기예매 별 예매 금액 비교
df_play.groupby('조기예매')['예매/취소금액'].mean()
# Out:
# 조기예매
# 0    33559.892890
# 1    35910.269713
# Name: 예매/취소금액, dtype: float64

# %%
# 조기예매 별 예매 금액 박스플롯
sns.boxplot(x='조기예매', y='예매/취소금액', data=df_play)
plt.title('Prices of Early Buying')
plt.xlabel('Early Buying O X')
plt.ylabel('Prices')
plt.show()

# %%
# 조기예매 별 성별 분포 비교
df_play.groupby('조기예매')['성별'].value_counts()
# Out:
# 조기예매  성별
# 0     2     13976
#       1     10646
#       0      4787
# 1     2      6370
#       1      3901
#       0       889
# Name: count, dtype: int64

# %%
# 빈도수 계산
df_counts = df_play.groupby(['조기예매', '성별']).size().reset_index(name='count')

# 막대 그래프 그리기
sns.barplot(x='조기예매', y='count', hue='성별', data=df_counts)
plt.title('Gender Distn by Early Buying')
plt.xlabel('Early buying')
plt.ylabel('Freq')
plt.show()

# %%
# 조기 예매 별 예매처 비교
df_play.groupby('조기예매')['예매/취소방식명(관리시스템)'].value_counts()
# Out:
# 조기예매  예매/취소방식명(관리시스템)
# 0     모바일                20906
#       웹                   8503
# 1     모바일                 8376
#       웹                   2784
# Name: count, dtype: int64

# %%
# 빈도수 계산
df_counts = df_play.groupby(['조기예매', '예매/취소방식명(관리시스템)']).size().reset_index(name='count')

# 막대 그래프 그리기
sns.barplot(x='조기예매', y='count', hue='예매/취소방식명(관리시스템)', data=df_counts)
plt.title('Way Distn by Early Buying')
plt.xlabel('Early buying')
plt.ylabel('Freq')
plt.show()

# %% [markdown]
# ### 좌석 등급

# %%
df_play['좌석등급'].value_counts()
# Out:
# 좌석등급
# 전석(35000)                            13561
# 전석(40000)                             9045
# 전석(30000)                             2284
# VIP석(90000), S석(70000), S석(60000)     1599
# R석(77000), S석(66000)                  1504
# 전석(55000)                             1421
# R석(35000), S석(30000)                  1275
# 전석(50000)                             1043
# R석(66000), S석(44000)                   871
# R석(35000), S석(25000)                   829
# 전석(70000)                              690
# 전석(38000)                              619
# R석(55000), S석(33000)                   618
# R석(44000), S석(33000)                   598
# R석(60000), S석(40000)                   581
# R석(70000), S석(50000), A석(40000)        484
# R석(70000), S석(50000)                   457
# R석(60000), S석(45000), A석(30000)        390
# VIP석(88000), R석(66000), S석(44000)      377
# 전석무료(0)                                333
# R석(55000), S석(45000)                   303
# R석(30000), S석(20000)                   260
# 전석(45000)                              238
# VIP석(45000), R석(40000)                 209
# R석(55000), S석(44000)                   160
# 전석(44000)                              155
# R석(35000)                              123
# 전석(63000)                              116
# 전석(25000)                              107
# 전석(15000)                               92
# 전석(20000)                               74
# 전석(69000)                               64
# 전석(5000)                                33
# 전석(66000)                               33
# VIP석(30000)                              6
# Name: count, dtype: int64

# %% [markdown]
# ### 스타배우 영향

# %%
lst=['최정원', '고준희', '신성록', '차승원', '진선규', '엄기준', '양지원', '나문희', '봉태규', '김선영', '김수미', '고두심', '염혜란',
     '문소리', '박정원', '박은석', '박해수', '박소담', '정성일', '지현준', '이순재', '신구', '홍승안', '정휘', '전성우', '박정복', '전동석',
     '강홍석', '조승우', '옥주현', '정선아', '민경아', '김선영', '최재림', '전미도', '카이', '김준수', '홍강호', '박효신', '박강현', '정성화', '규현',
     '박은태', '박성훈', '조정석', '김승우', '지창욱', '홍광호', '신영숙', '차지연', '지창욱', '한지상', '마이클리', '김소현', '박건형', '윤공주', '바다', '서범석', '아이비']

# 스타배우 칼럼 추가
# 스타배우 칼럼 추가
# 스타배우 칼럼 추가
df_play['스타배우'] = df_play['출연진내용'].apply(
    lambda x: 1 if isinstance(x, str) and any(actor in x.split(', ') for actor in lst) else 0
)

df_play['스타배우'].value_counts()
# Out:
# <ipython-input-73-366bdc049cd2>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_play['스타배우'] = df_play['출연진내용'].apply(
# 스타배우
# 0    39873
# 1      696
# Name: count, dtype: int64

# %%
# 파워칼럼
# 파워 칼럼 계산: 장당금액 * 좌석 수
df_play['파워'] = df_play['장당금액'] * df_play['좌석수']

# 스타배우 사용 여부에 따라 데이터 나누기
power_with_stars = df_play[df_play['스타배우'] == 1]['파워']
power_without_stars = df_play[df_play['스타배우'] == 0]['파워']

# 시각화
plt.figure(figsize=(12, 6))

# 히스토그램
plt.subplot(1, 2, 1)
sns.histplot(power_with_stars, bins=10, color='blue', kde=True, label='Star', stat='density')
sns.histplot(power_without_stars, bins=10, color='orange', kde=True, label='Nonstar', stat='density')
plt.title('Power Distn (Histogram)')
plt.xlabel('Power')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# <ipython-input-74-fe00685e0a77>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_play['파워'] = df_play['장당금액'] * df_play['좌석수']
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
power_with_stars = df_play[df_play['스타배우'] == 1]['파워']
power_without_stars = df_play[df_play['스타배우'] == 0]['파워']

sns.boxplot(power_with_stars)
plt.title('Star Power')
plt.show()
sns.boxplot(power_without_stars)
plt.title('Nonstar Power')
plt.show()

# %% [markdown]
# # EDA_뮤지컬

# %% [markdown]
# ### 공연코드

# %%
df_musical['공연코드'].value_counts()
# Out:
# 공연코드
# PF316185    7130
# PF311592    5660
# PF422052    5492
# PF422296    4726
# PF311529    4669
#             ...
# PF425637       6
# PF425288       6
# PF394325       4
# PF422261       3
# PF377742       3
# Name: count, Length: 74, dtype: int64

# %% [markdown]
# ### 공연일시에 따른 가격

# %%
df_musical['공연일시']=pd.to_datetime(df_musical['공연일시'])

# 시각화: 공연일시별 평균 장당금액 변화
mean_price = df_musical.groupby('공연일시')['장당금액'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(x='공연일시', y='장당금액', data=mean_price, marker='o')
plt.title('Ticket Price by Performance Time')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-77-55ed5fc0e369>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_musical['공연일시']=pd.to_datetime(df_musical['공연일시'])

# %% [markdown]
# ### 예매/취소매수

# %%
df_musical['예매/취소매수'].value_counts()
# Out:
# 예매/취소매수
# 1    74704
# Name: count, dtype: int64

# %% [markdown]
# ### 예매/취소 금액

# %%
df_musical['예매/취소금액'].value_counts()
# Out:
# 예매/취소금액
# 150000    9116
# 120000    5041
# 130000    4723
# 140000    3292
# 70000     3262
#           ...
# 32800        1
# 10800        1
# 102600       1
# 59850        1
# 50050        1
# Name: count, Length: 208, dtype: int64

# %%
df_musical['예매/취소금액'].value_counts().sort_index(ascending=False)
# Out:
# 예매/취소금액
# 290000     970
# 224500      16
# 204500       4
# 194500      62
# 190000    1614
#           ...
# 8000        14
# 7000        17
# 6000        73
# 5000        14
# 0           22
# Name: count, Length: 208, dtype: int64

# %%
# 예매취소금액 분포
# 예매취소금액이 0인 것은 결측치로 처리하고 제거

df_musical_price=df_musical[df_musical['예매/취소금액']!=0]

# 시각화: 금액 분포 박스 플롯
plt.figure(figsize=(8, 6))
sns.boxplot(y='예매/취소금액', data=df_musical_price, showfliers=False)
plt.show()

# 시각화: 금액 분포 히스토그램
plt.figure(figsize=(8, 6))
sns.histplot(df_musical_price['예매/취소금액'], kde=True)
plt.show()

# %%
# 시각화: 공연일시별 평균 예매금액 변화
mean_price = df_musical_price.groupby('공연일시')['예매/취소금액'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(x='공연일시', y='예매/취소금액', data=mean_price, marker='o')
plt.title('Ticket Price by Performance Time')
plt.xticks(rotation=45)
plt.show()

# %%
df_musical.groupby('재관람')['예매/취소금액'].describe()
# Out:
#        count           mean           std      min      25%       50%  \
# 재관람
# 0    74699.0  104350.434477  50861.305867      0.0  61600.0  117000.0
# 1        5.0   63920.000000  30015.196151  42000.0  42000.0   42000.0
#
#           75%       max
# 재관람
# 0    140000.0  290000.0
# 1     96800.0   96800.0

# %%
df_musical[df_musical['재관람']==1].shape
# Out:
# (5, 27)

# %%
# 재관람과 비재관람 데이터의 예매/취소 금액 차이

# 박스 플롯 시각화: 재관람 여부에 따른 예매/취소금액 비교
plt.figure(figsize=(10, 6))
sns.boxplot(x='재관람', y='예매/취소금액', data=df_musical, showfliers=True)
plt.title('Comparison of price by reviewing')
plt.xlabel('Review (0: non, 1: re)')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ### 예매/취소방식명

# %%
df_musical['예매/취소방식명(관리시스템)'].value_counts()
# Out:
# 예매/취소방식명(관리시스템)
# 모바일    43843
# 웹      30861
# Name: count, dtype: int64

# %%
# 장당금액 웹 vs 모바일
plt.figure(figsize=(10, 6))
sns.boxplot(x='예매/취소방식명(관리시스템)', y='장당금액', data=df_musical)
plt.xlabel('Web vs Mobile')
plt.ylabel('A ticket Price')
plt.show()

# %%
# 할인금액 웹 vs 모바일
# 시각화: 웹 vs 모바일 장당금액 비교 (박스 플롯)
plt.figure(figsize=(10, 6))
sns.boxplot(x='예매/취소방식명(관리시스템)', y='할인금액', data=df_musical, showfliers=False)
plt.xlabel('Web vs Mobile')
plt.ylabel('Price')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 할인금액의 분포를 히스토그램으로 시각화 (웹 vs 모바일)
plt.figure(figsize=(10, 6))
sns.histplot(data=df_musical, x='할인금액', hue='예매/취소방식명(관리시스템)', kde=True, multiple='stack')
plt.title('Discount Distn: Web vs Mobile')
plt.xlabel('Discount')
plt.ylabel('Freq')
plt.show()

# %%
# 구매처 별 재관람 건수 시각화
revisit_ratio = df_musical.groupby('예매/취소방식명(관리시스템)')['재관람'].sum().reset_index()

# 바 그래프 시각화
plt.figure(figsize=(8, 6))
sns.barplot(x='예매/취소방식명(관리시스템)', y='재관람', data=revisit_ratio)
plt.title('Review Events by Web vs Mobile')
plt.xlabel('Web vs Mobile')
plt.ylabel('Review')
plt.show()

# %%
# 예매방식명별로 재관람 비율 계산
# 재관람의 비율은 '재관람' 값이 1인 경우의 평균으로 계산할 수 있습니다.
revisit_ratio = df_musical.groupby('예매/취소방식명(관리시스템)')['재관람'].mean().reset_index()

# 바 그래프 시각화
plt.figure(figsize=(8, 6))
sns.barplot(x='예매/취소방식명(관리시스템)', y='재관람', data=revisit_ratio)
plt.title('웹 vs 모바일 재관람 비율 비교')
plt.xlabel('예매 방식')
plt.ylabel('재관람 비율')
plt.ylim(0, 0.1)
plt.show()

# %% [markdown]
# ### 성별

# %%
df_musical['성별'].value_counts()
# Out:
# 성별
# 2    45495
# 1    21803
# 0     7406
# Name: count, dtype: int64

# %%
# 성별 웹 vs 모바일

# 성별 및 예매/취소방식명(관리시스템)별 빈도 계산
gender_distribution = df_musical.groupby(['예매/취소방식명(관리시스템)', '성별']).size().reset_index(name='count')

# 시각화: 웹 vs 모바일 성별 분포 바 그래프
plt.figure(figsize=(10, 6))
sns.barplot(x='예매/취소방식명(관리시스템)', y='count', hue='성별', data=gender_distribution)
plt.title('Gender Distribution: Web vs Mobile')
plt.xlabel('Web vs Mobile')
plt.ylabel('Gender')
plt.legend(title='gender', labels=['0','1', '2'])  # 성별에 맞는 레이블 설정
plt.show()

# %%
# 성별 별 예매금액의 차이

# 1. 성별 값이 0인 데이터를 제거 (0은 결측치로 간주)
df_filtered = df_musical[df_musical['성별'] != 0]

plt.figure(figsize=(10, 6))
sns.violinplot(x='성별', y='예매/취소금액', data=df_filtered)
plt.title('Price Comparison by Gender (Violin Plot)')
plt.xlabel('Gender (1: Men, 2: Women)')
plt.ylabel('Prices')
plt.xticks(ticks=[0, 1], labels=['Men', 'Women'])  # 성별 레이블 설정
plt.show()

# %%
# 성별 별 장당금액의 차이
# 1. 성별 값이 0인 데이터를 제거 (0은 결측치로 간주)
df_filtered = df_musical[df_musical['성별'] != 0]

plt.figure(figsize=(10, 6))
sns.violinplot(x='성별', y='장당금액', data=df_filtered)
plt.title('Ticket Price Comparison by Gender (Violin Plot)')
plt.xlabel('Gender (1: Men, 2: Women)')
plt.ylabel('Prices')
plt.xticks(ticks=[0, 1], labels=['Men', 'Women'])  # 성별 레이블 설정
plt.show()

# %%
# 성별 별 극장 규모의 차이

df_filtered = df_musical[df_musical['성별'] != 0]

# 2. 성별별 극장 규모 분포를 시각화 (countplot 사용)
plt.figure(figsize=(10, 6))
sns.countplot(x='극장규모', hue='성별', data=df_filtered)
plt.title('Theatre Scale by Gender')
plt.xlabel('Theatre scale (0: Small, 1: Medium, 2: Large)')
plt.ylabel('Freq')
plt.xticks(ticks=[0, 1, 2], labels=['Small', 'Medium', 'Large'])
plt.legend(title='gender', labels=['Men', 'Women'])
plt.show()

# %%
# 성별 별 재관람율의 차이
# 1. 성별 값이 0인 데이터를 제거 (0은 결측치로 간주)
df_filtered = df_musical[df_musical['성별'] != 0]

# 2. 성별별 재관람율 계산
total_counts_by_gender = df_filtered.groupby('성별')['재관람'].count().reset_index(name='총예매수')
revisit_counts_by_gender = df_filtered.groupby('성별')['재관람'].sum().reset_index(name='재관람수')

# 3. 재관람율 계산 (재관람수 / 총예매수)
revisit_ratio_by_gender = pd.merge(revisit_counts_by_gender, total_counts_by_gender, on='성별')
revisit_ratio_by_gender['재관람율'] = revisit_ratio_by_gender['재관람수'] / revisit_ratio_by_gender['총예매수']

# 4. 바 그래프 시각화
plt.figure(figsize=(8, 6))
plt.bar(revisit_ratio_by_gender['성별'].map({1: 'Men', 2: 'Women'}), revisit_ratio_by_gender['재관람율'])
plt.title('Review Proportion Comparison by Gender')
plt.xlabel('gender')
plt.ylabel('Review')
plt.ylim(0, 0.1)  # 비율이므로 y축 범위를 0에서 1로 설정

# 그래프 표시
plt.show()

# %% [markdown]
# ### 연령

# %%
# 1. 연령이 (0, 100) 사이는 이상치로 처리하고 제거
df_filtered = df_musical[(df_musical['연령'] >= 0) & (df_musical['연령'] < 100)]

# 2. 연령 분포 시각화 (히스토그램)
plt.figure(figsize=(10, 6))
sns.histplot(df_filtered['연령'], bins=30, kde=True)
plt.title('Age Distn')
plt.xlabel('Age')
plt.ylabel('Freq')
plt.show()

# %%
# 성별 별 연령분포
df_filtered = df_musical[df_musical['성별'] != 0]

# 2. 연령 분포 시각화 (히스토그램)
plt.figure(figsize=(10, 6))
sns.histplot(data=df_filtered, x='연령', hue='성별', bins=30, kde=True, multiple='stack')
plt.title('Age Distn by Gender')
plt.xlabel('Age')
plt.ylabel('Freq')
plt.legend(title='gender', labels=['M', 'W'])
plt.show()

# %%
# 재관람 여부 별 연령 분포의 차이
df_filtered= df_musical[(df_musical['연령'] >= 0) & (df_musical['연령'] < 100)]
plt.figure(figsize=(10, 6))
sns.histplot(data=df_filtered, x='연령', hue='재관람', bins=30, kde=True, multiple='stack')
plt.title('Age distn by reviewing')
plt.xlabel('Age')
plt.ylabel('Freq')
plt.legend(title='Review', labels=['re', 'non'])
plt.show()

# %%
# 1. 재관람 여부 별 연령 분포 시각화 (박스 플롯)
plt.figure(figsize=(10, 6))
sns.boxplot(x='재관람', y='연령', data=df_filtered)
plt.xlabel('Reviewing (0: non, 1: re)')
plt.ylabel('Age')
plt.xticks(ticks=[0, 1], labels=['non', 're'])
plt.show()

# %%
# 연령 별 극장 규모 차이

# 1. 연령 별 극장 규모 시각화 (박스 플롯)
plt.figure(figsize=(10, 6))
sns.boxplot(x='극장규모', y='연령', data=df_filtered)
plt.title('연령 별 극장 규모 차이 (박스 플롯)')
plt.xlabel('극장 규모 (0: 소극장, 1: 중극장, 2: 대극장)')
plt.ylabel('연령')
plt.xticks(ticks=[0, 1, 2], labels=['소극장', '중극장', '대극장'])
plt.show()

# 2. 연령 별 극장 규모 시각화 (바이올린 플롯)
plt.figure(figsize=(10, 6))
sns.violinplot(x='극장규모', y='연령', data=df_filtered)
plt.title('연령 별 극장 규모 차이 (바이올린 플롯)')
plt.xlabel('극장 규모 (0: 소극장, 1: 중극장, 2: 대극장)')
plt.ylabel('연령')
plt.xticks(ticks=[0, 1, 2], labels=['소극장', '중극장', '대극장'])
plt.show()

# %% [markdown]
# ### 공연지역명

# %%
df_musical['공연지역명'].value_counts()
# Out:
# 공연지역명
# 서울     51055
# 경상도    14395
# 경기도     6084
# 충청도     1581
# 강원도     1103
# 전라도      281
# 제주도      205
# Name: count, dtype: int64

# %%
# 공연지역명 별 극장 규모 조회
df_musical.groupby('공연지역명')['극장규모'].value_counts()
# Out:
# 공연지역명  극장규모
# 강원도    1        1103
# 경기도    2        4726
#        1        1358
# 경상도    2       13607
#        0         692
#        1          96
# 서울     2       34307
#        1       12693
#        0        4055
# 전라도    0         281
# 제주도    1         168
#        0          37
# 충청도    2        1483
#        0          98
# Name: count, dtype: int64

# %%
# 공연 지역명 별 장당 가격 비교
# 공연지역명 별 극장 규모 조회
df_musical.groupby('공연지역명')['장당금액'].mean()
# Out:
# 공연지역명
# 강원도     22932.910245
# 경기도    100131.656805
# 경상도    109753.709621
# 서울     109517.752914
# 전라도     20761.565836
# 제주도     27707.317073
# 충청도     56263.124605
# Name: 장당금액, dtype: float64

# %%
# 공연 지역 별 재관람율 비교
df_musical.groupby('공연지역명')['재관람'].mean()
# Out:
# 공연지역명
# 강원도    0.000000
# 경기도    0.000000
# 경상도    0.000000
# 서울     0.000098
# 전라도    0.000000
# 제주도    0.000000
# 충청도    0.000000
# Name: 재관람, dtype: float64

# %%
# 공연 지역 별 재관람 비교
df_musical.groupby('공연지역명')['재관람'].sum()
# Out:
# 공연지역명
# 강원도    0
# 경기도    0
# 경상도    0
# 서울     5
# 전라도    0
# 제주도    0
# 충청도    0
# Name: 재관람, dtype: int64

# %% [markdown]
# ### 내한공연여부

# %%
df_musical['내한공연 여부'].value_counts()
# Out:
# 내한공연 여부
# N    61340
# Y    13364
# Name: count, dtype: int64

# %%
df_musical.groupby('내한공연 여부')['장당금액'].mean()
# Out:
# 내한공연 여부
# N     98132.946283
# Y    141186.815325
# Name: 장당금액, dtype: float64

# %%
# 박스플롯 시각화
plt.figure(figsize=(8, 6))
sns.boxplot(x='내한공연 여부', y='장당금액', data=df_musical, palette=["blue", "orange"])
plt.ylabel('Price')
plt.show()
# Out:
# <ipython-input-110-cda8f3e1639c>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='내한공연 여부', y='장당금액', data=df_musical, palette=["blue", "orange"])

# %%
# 내한공연 별 재관람 횟수 관찰
df_musical.groupby('내한공연 여부')['재관람'].sum()
# Out:
# 내한공연 여부
# N    3
# Y    2
# Name: 재관람, dtype: int64

# %%
# 내한공연 별 재관람율 관찰
df_musical.groupby('내한공연 여부')['재관람'].mean()
# Out:
# 내한공연 여부
# N    0.000049
# Y    0.000150
# Name: 재관람, dtype: float64

# %% [markdown]
# ### 오픈런 여부

# %%
df_musical['오픈런 여부'].value_counts()
# Out:
# 오픈런 여부
# N    72834
# Y     1870
# Name: count, dtype: int64

# %%
# 오픈런 여부 별 장당 금액 비교
df_musical.groupby('오픈런 여부')['장당금액'].mean()
# Out:
# 오픈런 여부
# N    107662.465675
# Y     34656.417112
# Name: 장당금액, dtype: float64

# %%
# 오픈런 여부 별 박스플롯
sns.boxplot(x='오픈런 여부', y='장당금액', data=df_musical)
plt.title('Prices of Open Run')
plt.xlabel('Open run O X')
plt.ylabel('Prices')
plt.show()

# %%
# 오픈런 여부 별 극장규모 비교
df_musical.groupby('오픈런 여부')['극장규모'].value_counts()
# Out:
# 오픈런 여부  극장규모
# N       2       54123
#         1       14677
#         0        4034
# Y       0        1129
#         1         741
# Name: count, dtype: int64

# %%
# 오픈런 여부 별 재관람율 비교
df_musical.groupby('오픈런 여부')['재관람'].mean()
# Out:
# 오픈런 여부
# N    0.000069
# Y    0.000000
# Name: 재관람, dtype: float64

# %%
df_musical.groupby('오픈런 여부')['재관람'].sum()
# Out:
# 오픈런 여부
# N    5
# Y    0
# Name: 재관람, dtype: int64

# %% [markdown]
# ### 조기예매

# %%
# 조기예매 별 예매 금액 비교
df_musical.groupby('조기예매')['예매/취소금액'].mean()
# Out:
# 조기예매
# 0     99947.418807
# 1    108689.758916
# Name: 예매/취소금액, dtype: float64

# %%
# 조기예매 별 예매 금액 박스플롯
sns.boxplot(x='조기예매', y='예매/취소금액', data=df_musical)
plt.title('Prices of Early Buying')
plt.xlabel('Early Buying O X')
plt.ylabel('Prices')
plt.show()

# %%
# 조기예매 별 성별 분포 비교
df_musical.groupby('조기예매')['성별'].value_counts()
# Out:
# 조기예매  성별
# 0     2     19896
#       1     12382
#       0      4825
# 1     2     25599
#       1      9421
#       0      2581
# Name: count, dtype: int64

# %%
# 빈도수 계산
df_counts = df_musical.groupby(['조기예매', '성별']).size().reset_index(name='count')

# 막대 그래프 그리기
sns.barplot(x='조기예매', y='count', hue='성별', data=df_counts)
plt.title('Gender Distn by Early Buying')
plt.xlabel('Early buying')
plt.ylabel('Freq')
plt.show()

# %%
# 조기 예매 별 예매처 비교
df_musical.groupby('조기예매')['예매/취소방식명(관리시스템)'].value_counts()
# Out:
# 조기예매  예매/취소방식명(관리시스템)
# 0     모바일                22615
#       웹                  14488
# 1     모바일                21228
#       웹                  16373
# Name: count, dtype: int64

# %%
# 빈도수 계산
df_counts = df_musical.groupby(['조기예매', '예매/취소방식명(관리시스템)']).size().reset_index(name='count')

# 막대 그래프 그리기
sns.barplot(x='조기예매', y='count', hue='예매/취소방식명(관리시스템)', data=df_counts)
plt.title('Way Distn by Early Buying')
plt.xlabel('Early buying')
plt.ylabel('Freq')
plt.show()

# %% [markdown]
# ### 좌석등급

# %%
df_musical['좌석등급'].value_counts()
# Out:
# 좌석등급
# VIP석(150000), R석(130000), S석(100000), A석(70000)                            10329
# VIP석(290000), R석(190000), S석(150000), A석(120000), B석(90000), C석(70000)      7130
# VIP석(180000), R석(150000), S석(120000), A석(90000)                             5492
# VIP석(150000), R석(130000), S석(90000), A석(70000)                              4726
# R석(66000), S석(44000)                                                        3811
# R석(66000), S석(55000)                                                        3703
# VIP석(150000), OP석(140000), R석(130000), S석(100000), A석(80000), B석(60000)     3227
# VIP석(170000), 젤리클석(170000), R석(140000), S석(110000), A석(80000)               3170
# OP석(140000), VIP석(140000), R석(120000), S석(100000), A석(70000)                3121
# 전석(121000)                                                                  3064
# VIP석(160000), R석(130000), S석(100000), A석(70000)                             3043
# VIP석(150000), R석(120000), S석(80000), A석(60000)                              2962
# VIP석(150000), OP석(140000), R석(130000), S석(100000), A석(70000)                2859
# VIP석(150000), R석(130000), S석(100000), A석(80000)                             2563
# R석(140000), OP석(140000), S석(100000), A석(70000)                              2362
# R석(88000), S석(77000), A석(55000)                                             1604
# R석(120000), S석(90000), A석(60000)                                            1549
# R석(70000), S석(50000)                                                        1483
# 전석(50000)                                                                    886
# VIP석(110000), R석(88000), S석(66000), A석(33000)                                829
# R석(20000), S석(10000)                                                         682
# R석(50000), S석(30000), A석(10000)                                              679
# 전석(35000)                                                                    641
# VIP석(66000), S석(55000), A석(44000)                                            573
# 전석(40000)                                                                    552
# 전석(65000)                                                                    533
# 전석(45000)                                                                    489
# R석(30000), S석(20000)                                                         436
# 전석(20000)                                                                    424
# R석(60000), 시야제한석(45000)                                                      335
# 전석(22500)                                                                    330
# 전석(60000)                                                                    323
# 전석(55000)                                                                    205
# VIP석(60000), S석(50000), A석(40000)                                            168
# 사전예약(27000)                                                                   96
# R석(88000), S석(77000), A석(66000)                                               93
# VIP석(70000), R석(50000)                                                        66
# 전석(30000)                                                                     57
# R석(77000), S석(66000), A석(55000)                                               35
# 화,수,목(40000), 금,토,일,공휴일(50000)                                                31
# 전석(16000)                                                                     25
# R석(40000), S석(30000)                                                          14
# R석(50000), S석(40000)                                                           4
# Name: count, dtype: int64

# %% [markdown]
# ### 스타배우 영향

# %% [markdown]
# 스타배우 출연진이 영향이 있는지를 판별.
#
# 객석 x 장당 가격으로 파워 살펴보기
#
# 스타배우 칼럼 : 1이면 스타배우 극, 0이면 아님

# %%
lst=['최정원', '고준희', '신성록', '차승원', '진선규', '엄기준', '양지원', '나문희', '봉태규', '김선영', '김수미', '고두심', '염혜란',
     '문소리', '박정원', '박은석', '박해수', '박소담', '정성일', '지현준', '이순재', '신구', '홍승안', '정휘', '전성우', '박정복', '전동석',
     '강홍석', '조승우', '옥주현', '정선아', '민경아', '김선영', '최재림', '전미도', '카이', '김준수', '홍강호', '박효신', '박강현', '정성화', '규현',
     '박은태', '박성훈', '조정석', '김승우', '지창욱', '홍광호', '신영숙', '차지연', '지창욱', '한지상', '마이클리', '김소현', '박건형', '윤공주', '바다', '서범석', '아이비']

# 스타배우 칼럼 추가
# 스타배우 칼럼 추가
# 스타배우 칼럼 추가
df_musical['스타배우'] = df_musical['출연진내용'].apply(
    lambda x: 1 if isinstance(x, str) and any(actor in x.split(', ') for actor in lst) else 0
)

df_musical['스타배우'].value_counts()
# Out:
# <ipython-input-126-1c1802cae482>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_musical['스타배우'] = df_musical['출연진내용'].apply(
# 스타배우
# 1    42509
# 0    32195
# Name: count, dtype: int64

# %%
# 파워칼럼
# 파워 칼럼 계산: 장당금액 * 좌석 수
df_musical['파워'] = df_musical['장당금액'] * df_musical['좌석수']

# 스타배우 사용 여부에 따라 데이터 나누기
power_with_stars = df_musical[df_musical['스타배우'] == 1]['파워']
power_without_stars = df_musical[df_musical['스타배우'] == 0]['파워']

# 시각화
plt.figure(figsize=(12, 6))

# 히스토그램
plt.subplot(1, 2, 1)
sns.histplot(power_with_stars, bins=10, color='blue', kde=True, label='Star', stat='density')
sns.histplot(power_without_stars, bins=10, color='orange', kde=True, label='Nonstar', stat='density')
plt.title('Power Distn (Histogram)')
plt.xlabel('Power')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# <ipython-input-127-89212be45ad8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_musical['파워'] = df_musical['장당금액'] * df_musical['좌석수']
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
power_with_stars = df_musical[df_musical['스타배우'] == 1]['파워']
power_without_stars = df_musical[df_musical['스타배우'] == 0]['파워']

sns.boxplot(power_with_stars)
plt.title('Star Power')
plt.show()
sns.boxplot(power_without_stars)
plt.title('Nonstar Power')
plt.show()

# %% [markdown]
# ## 상관관계 파악

# %%
# 연극
# 데이터프레임의 수치형 칼럼만 선택
numeric_df = df_play.select_dtypes(include=[float, int])

# 상관관계 계산
correlation_matrix = numeric_df.corr()

# 상관관계 히트맵 시각화
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar_kws={"shrink": .8})
plt.title('Heatmap')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 뮤지컬
# 데이터프레임의 수치형 칼럼만 선택
numeric_df = df_musical.select_dtypes(include=[float, int])

# 상관관계 계산
correlation_matrix = numeric_df.corr()

# 상관관계 히트맵 시각화
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar_kws={"shrink": .8})
plt.title('Heatmap')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
