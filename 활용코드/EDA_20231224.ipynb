# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 3s (3,417 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 123594 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %% [markdown]
# 런타임 재시작

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'NanumGothic'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 임의의 데이터 생성
x = np.linspace(0, 10, 100)
y = np.sin(x)

# 간단한 시각화
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='사인 곡선', color='blue')
plt.title('한글 폰트 확인', fontsize=16)
plt.xlabel('X축', fontsize=14)
plt.ylabel('Y축', fontsize=14)
plt.legend()
plt.grid()

# 결과 출력
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("/content/drive/MyDrive/KOPIS공모전/데이터/(데이터) 23년(240524)/(임형수)_2023_12_24_643,306.xlsx")
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     전송사업자코드  전송사업자명    공연시설코드       시설특성    개관연도  \
# 0  SE000318      쿠팡  FC222961    민간(대학로)  2017.0
# 1  SE000318      쿠팡  FC222961    민간(대학로)  2017.0
# 2  SE000303  네이버N예약  FC224674  민간(대학로 외)     NaN
# 3  SE000303  네이버N예약  FC224674  민간(대학로 외)     NaN
# 4  SE000303  네이버N예약  FC224674  민간(대학로 외)     NaN
#
#                              주소 편의시설_레스토랑 여부 편의시설_카페 여부 편의시설_편의점 여부  \
# 0  서울특별시 종로구 대학로8가길 36 (동숭동) 3층            Y          N           N
# 1  서울특별시 종로구 대학로8가길 36 (동숭동) 3층            Y          N           N
# 2      대구광역시 달성군 화원읍 비슬로520길 6             N          N           N
# 3      대구광역시 달성군 화원읍 비슬로520길 6             N          N           N
# 4      대구광역시 달성군 화원읍 비슬로520길 6             N          N           N
#
#   편의시설_놀이방 여부  ... 아동공연 여부 축제 여부 내한공연 여부 오픈런 여부               판매시작일시  \
# 0           N  ...       N     N       N      Y  2023/11/24 11:13:53
# 1           N  ...       N     N       N      Y  2023/11/24 11:13:53
# 2           N  ...       Y     N       N      N  2023/12/16 00:00:00
# 3           N  ...       Y     N       N      N  2023/12/16 00:00:00
# 4           N  ...       Y     N       N      N  2023/12/16 00:00:00
#
#                 판매종료일시       좌석등급 단독판매여부  판매좌석수  \
# 0  2099/12/31 23:59:59  전석(35000)      N    10석
# 1  2099/12/31 23:59:59  전석(35000)      N    10석
# 2  2024/02/29 00:00:00  전석(25000)      N      1
# 3  2024/02/29 00:00:00  전석(25000)      N      1
# 4  2024/02/29 00:00:00  전석(25000)      N      1
#
#                                             판매페이지URL
# 0  https://trip.coupang.com/tp/products/100000013243
# 1  https://trip.coupang.com/tp/products/100000013243
# 2  https://booking.naver.com/booking/12/bizes/104...
# 3  https://booking.naver.com/booking/12/bizes/104...
# 4  https://booking.naver.com/booking/12/bizes/104...
#
# [5 rows x 68 columns]

# %%
df.columns
# Out:
# Index(['전송사업자코드', '전송사업자명', '공연시설코드', '시설특성', '개관연도', '주소', '편의시설_레스토랑 여부',
#        '편의시설_카페 여부', '편의시설_편의점 여부', '편의시설_놀이방 여부', '편의시설_수유실 여부',
#        '장애인시설_주차장 여부', '장애인시설_화장실 여부', '장애인시설_경사로 여부', '장애인시설_전용엘리베이터 여부',
#        '주차시설_자체 여부', '주차시설_공영 여부', '공연장코드', '좌석수', '장애인석', '무대시설_오케스트라피트 여부',
#        '무대시설_연습실 여부', '무대시설_분장실 여부', '무대시설_무대넓이', '공연코드', '공연회차', '공연일시',
#        '입장권고유번호', '예매/취소일시', '예매/취소구분', '예매/취소매수', '예매/취소금액', '예매/취소방식코드',
#        '예매/취소방식명(관리시스템)', '예매/취소방식명(전송처)', '결제수단코드', '결제수단명(관리시스템)',
#        '결제수단명(전송처)', '할인금액', '할인종류코드', '할인종류명(관리시스템)', '할인종류명(전송처)', '장당금액',
#        '성별', '연령', '공연시작일자', '공연종료일자', '소요시간', '장르명', '세부장르명', '공연지역명',
#        '출연진내용', '제작진내용', '기획제작사명', '원작자명', '극작가명', '수상실적', '관람연령', '아동공연 여부',
#        '축제 여부', '내한공연 여부', '오픈런 여부', '판매시작일시', '판매종료일시', '좌석등급', '단독판매여부',
#        '판매좌석수', '판매페이지URL'],
#       dtype='object')

# %%
columns_to_select = ['좌석수', '공연코드', '공연일시', '예매/취소일시', '예매/취소구분',
                     '예매/취소매수', '예매/취소금액', '예매/취소방식명(관리시스템)',
                     '할인금액', '할인종류명(전송처)', '장당금액', '성별', '연령',
                     '공연시작일자', '공연종료일자', '장르명', '공연지역명',
                     '출연진내용', '아동공연 여부', '내한공연 여부',
                     '오픈런 여부', '판매시작일시', '판매종료일시', '좌석등급']

# DataFrame에서 선택한 열만 포함
df = df.loc[:, columns_to_select]
df.columns
# Out:
# Index(['좌석수', '공연코드', '공연일시', '예매/취소일시', '예매/취소구분', '예매/취소매수', '예매/취소금액',
#        '예매/취소방식명(관리시스템)', '할인금액', '할인종류명(전송처)', '장당금액', '성별', '연령', '공연시작일자',
#        '공연종료일자', '장르명', '공연지역명', '출연진내용', '아동공연 여부', '내한공연 여부', '오픈런 여부',
#        '판매시작일시', '판매종료일시', '좌석등급'],
#       dtype='object')

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# ##예매취소 데이터 제거

# %%
df['예매/취소구분'].value_counts()
# Out:
# 예매/취소구분
# 1    94716
# Name: count, dtype: int64

# %%
df=df[df['예매/취소구분']==1]
df['예매/취소구분'].value_counts()
# Out:
# 예매/취소구분
# 1    451536
# Name: count, dtype: int64

# %% [markdown]
# ## 연령

# %%
df['연령'].describe()
# Out:
# count    451536.000000
# mean       1534.399372
# std         834.106626
# min           0.000000
# 25%        1966.000000
# 50%        1985.000000
# 75%        1993.000000
# max        2023.000000
# Name: 연령, dtype: float64

# %%
df['연령']=2024-df['연령']+1
df['연령'].describe()
# Out:
# <ipython-input-139-177572000844>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['연령']=2024-df['연령']+1
# count    451536.000000
# mean        490.600628
# std         834.106626
# min           2.000000
# 25%          32.000000
# 50%          40.000000
# 75%          59.000000
# max        2025.000000
# Name: 연령, dtype: float64

# %%
df['연령'].head(10)
# Out:
# 0    2025
# 1    2025
# 2      43
# 3      43
# 4      43
# 5      43
# 6      81
# 7      81
# 8      39
# 9      39
# Name: 연령, dtype: int64

# %% [markdown]
# 0에서 100 사이가 아닌건 모두 이상치이지만, 일단은 드롭하지 않는다.

# %% [markdown]
# ## 아동공연

# %%
df['아동공연 여부'].value_counts()
# Out:
# 아동공연 여부
# N    369455
# Y     82081
# Name: count, dtype: int64

# %%
df=df[df['아동공연 여부']=='N']
df['아동공연 여부'].value_counts()
# Out:
# 아동공연 여부
# N    369455
# Name: count, dtype: int64

# %% [markdown]
# ## 모바일, 웹만 남기기

# %%
df['예매/취소방식명(관리시스템)'].value_counts()
# Out:
# 예매/취소방식명(관리시스템)
# 모바일    166242
# 웹      125851
# 현장      51544
# 기타      23930
# 전화       1888
# Name: count, dtype: int64

# %%
df=df[(df['예매/취소방식명(관리시스템)']=='웹')|
      (df['예매/취소방식명(관리시스템)']=='모바일')]

df['예매/취소방식명(관리시스템)'].value_counts()
# Out:
# 예매/취소방식명(관리시스템)
# 모바일    166242
# 웹      125851
# Name: count, dtype: int64

# %% [markdown]
# ## 극장 규모 칼럼

# %% [markdown]
# 연극/ 뮤지컬 별로 다르다.
#
# <연극>
#
# 소극장 : 100석 미만
# 중극장 : 100- 300
# 대극장 : 300초과
# <뮤지컬>
#
# 소극장 : 300석 이하
# 중극장 : 300 - 1000
# 대극장 : 1000석 이상
# -> 소극장 = 0,중극장 =1, 대극장=2

# %%
# 연극과 뮤지컬 데이터만 필터링
df_filtered = df[(df['장르명'] == '연극') | (df['장르명'] == '뮤지컬')]

# 극장 크기 분류 함수 정의
def categorize_theater(row):
    if row['장르명'] == '연극':
        if row['좌석수'] < 100:
            return 0  # 소극장
        elif 100 <= row['좌석수'] < 300:
            return 1  # 중극장
        else:
            return 2  # 대극장
    elif row['장르명'] == '뮤지컬':
        if row['좌석수'] <= 300:
            return 0  # 소극장
        elif 300 < row['좌석수'] < 1000:
            return 1  # 중극장
        else:
            return 2  # 대극장

# 분류 기준 적용
df_filtered['극장규모'] = df_filtered.apply(categorize_theater, axis=1)
df_filtered['극장규모'].value_counts()
# Out:
# <ipython-input-145-a25025beb368>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['극장규모'] = df_filtered.apply(categorize_theater, axis=1)
# 극장규모
# 2    42026
# 1    41233
# 0    11457
# Name: count, dtype: int64

# %%
df_filtered.groupby('장르명')['극장규모'].value_counts()
# Out:
# 장르명  극장규모
# 뮤지컬  2       35502
#      1       16795
#      0        7939
# 연극   1       24438
#      2        6524
#      0        3518
# Name: count, dtype: int64

# %%
df=df_filtered
df.groupby('장르명')['극장규모'].value_counts()
# Out:
# 장르명  극장규모
# 뮤지컬  2       35502
#      1       16795
#      0        7939
# 연극   1       24438
#      2        6524
#      0        3518
# Name: count, dtype: int64

# %% [markdown]
# ## 재관람 칼럼

# %% [markdown]
# 재관람 = 1, 아니면 0

# %%
df['할인종류명(전송처)'].unique()
# Out:
# array([nan, '2차 크리스마스 뭉쳐라4인', '2차 크리스마스 의뢰인 할인', '3차 크리스마스 뭉쳐라3인',
#        '3차 크리스마스 의뢰인 할인', 'N', '정상가', '공연사 할인', '김종욱 찾기', '크리스마스 특별할인',
#        '기타', '판매자 할인쿠폰', '없음', '크리스마스 얼리버드 할인', '[12월 공연티켓 연말쿠폰] 비씨카드',
#        '[12월 공연티켓 연말쿠폰] 삼성카드', '[크리스마스] 조기예매 1인', '[크리스마스] 할인 1인', '일반',
#        '크리스마스 1인관람권', '인스타팔로우할인선착순 1인가', '크리스마스선착순1인가', '해녀 다이닝_런치 코스',
#        '1차 크리스마스 뭉쳐라4인', '크리스마스 1차 뭉쳐라4인!', '크리스마스 1차 뭉쳐라3인!',
#        '크리스마스 2차 일반 할인', '크리스마스 2차 뭉쳐라3인!', '크리스마스 2차 뭉쳐라4인!',
#        '크리스마스 3차 뭉쳐라4인!', '크리스마스 3차 일반 할인', '크리스마스 3차 뭉쳐라3인!',
#        '크리스마스 얼리버드', '크리스마스 2차 얼리버드', '크리스마스 깜짝 할인', '크리스마스 할인',
#        '크리스마스 할인가', '조조할인', '크리스마스 특별 할인', '크리스마스 특가할인', '핫세일',
#        '전석_크리스마스할인(조조)', '크리스마스', '정가', '크리스마스 관람권', '크리스마스 조기예매할인',
#        '크리스마스 특가(비지정석)', '크리스마스 할인세일', '함께즐겨요크리스마스특별할인', '크리스마스 선착순할인',
#        '해녀이야기', '[크리스마스] 얼리버드', '[크리스마스] 2차 얼리버드', '[크리스마스] 할인', '성탄티켓',
#        '커플티켓(2인)', '크리스마스할인(2인)', '크리스마스특가(1인)', '크리스마스할인(1인)',
#        '1차 크리스마스 뭉쳐라3인', '2차 크리스마스 뭉쳐라3인', '3차 크리스마스 뭉쳐라4인',
#        '고양문화재단회원 10,000원', '크리스마스 특별할인가', '크리스마스 1차 얼리버드', '크리스마스 할인권',
#        '해피할인', '일반석 정가', '일반석 크리스마스 할인', '전석 1인 관람권', '1차 크리스마스 할인',
#        '3차 크리스마스 할인', '크리스마스할인', '전석_주말특별할인', '크리스마스 일반특가', '네이버 직원 할인',
#        '모이면할인', '재관람할인', '커플할인', '초,중,고, 대학생', '크리스마스 사전예매',
#        '크리스마스 사전예매 1인', '크리스마스 특가할인 1인', '크리스마스 특별가', '사전예매',
#        '크리스마스조기예매할인', '특가석 이벤트', '정보 없음', 'R석 크리스마스 사전예매', 'R석 크리스마스할인',
#        '크리스마스 인스타팔로우할인가', '크리스마스(1인권)', '크리스마스(4인권)', '크리스마스(3인권)',
#        '크리스마스 1차 일반 할인', '크리스마스 특가', '직장인할인', '복지할인', '크리스마스 조조할인 특가',
#        '예매시(일반)', '크리스마스1인권', '산타특가', '성탄절특가', 'VIP석', 'S석', '루돌프특가',
#        '크리스마스 얼리버드할인', '[W공연티켓] 할인쿠폰', '클립할인', '네이버 특별 할인 30%',
#        '네이버 타임세일 50%', 'R석 2인 패키지', 'S석 2인 패키지', 'S석 청소년할인(1인1매)',
#        '크리스마스 조기예매 할인', '특별할인', '컴프롬쇼노트 할인', '연말할인', '네이버S석할인', '네이버R석할인',
#        '메리 크리스마스', '이만원의행복', '일반가', 'S석 네이버 연말특가', 'R석 가족할인', 'R석 정가',
#        'S석 정가', 'R석 재관람할인(1인1매)', '인스타그램할인', '[W공연티켓] 신한카드',
#        '[W공연티켓] 하나카드', '[W공연티켓] 비씨카드', '특별할인(1인2매/학생증 필수지참)',
#        '마지막 조기예매 할인', '재관람할인(본인만)', '[플레이위크] 스페셜쿠폰(12/7)', '겨울바람때문에공공공',
#        '균일석 얼리버드할인', 'A석', '연말할인 1인권', 'R석 미드나잇 마니아 할인(본인만)',
#        'R석 재관람 할인(본인만)', 'R석 우리의 프로텍션을 위해!', 'SNS(1인1매/업로드 인증)',
#        '개막 타임세일', '크리스마스티켓2', '패키지 할인가', 'R석 조기예매할인', 'R석 4인이상할인',
#        'S석 직장인할인(본인만)', 'R석 직장인할인(본인만)', 'S석 학생할인(본인만)', 'S석 4인이상할인',
#        'R석 학생할인(본인만)', '타임세일(VIP)', '연말 프로모션 할인', '사총사할인', '삼총사할인',
#        '조기예매할인', '장애인(1~3급 중증/동반1인)', '장애인(4~6급/경증,본인만)', '난타 [VIP석]',
#        '예매할인', '5매 이상 예매할인', '국가유공자(동반1인포함)', '타임세일', 'BNK 전용할인',
#        '예매 할인-주말', '카톡친구 할인-주말', '크리스마스이브 할인',
#        '[프리 R]고도를 기다리며 40% 할인쿠폰 4', '조기예매 20%', '문화패스(청소년 등) 30%',
#        '경로 50%', '장애인 50%', '국가유공자 50%', '엔톡(NTOK)회원 10%', '예술인패스카드 30%',
#        '파크컴퍼니 매니아 20%', '문화 릴레이(티켓) 20%', 'VIP석 2차 조기예매', 'VIP석 정가',
#        'VIP석 〈마리 퀴리〉 재관람 할인(1인1매)', 'VIP석 마리퀴리 팝업스토어 VIP석 50% 할인권(1인1매)',
#        'R석 마리퀴리 팝업스토어 R석 50% 할인권(1인1매)',
#        'VIP석 청소년할인(초중고학생본인_학생증빙필참,1인2매)', 'R석 2차 조기예매',
#        'VIP석 수험생할인(본인한정/수험생확인증빙지참)', 'R석 네이버 연말특가', 'VIP석 4인 패키지',
#        'VIP석 3인 패키지', 'R석 실험노트50%할인권소지자할인(1인1매)', 'R석 4인 패키지', '문화릴레이티켓',
#        '임직원할인', '청소년 할인', '보훈보상대상자', '2차 조기예매 할인',
#        '재관람 할인 (실물 유료 티켓  소지자 할인)', '네이버 지식쇼핑(5천원)', '멜론티켓 특별할인 쿠폰',
#        '네이버 지식쇼핑 V2(1천원)', '네이버 지식쇼핑(3천원)', '[몬테크리스토] 1차 관람 쿠폰',
#        '난타 [A석]', '자체할인', '학생할인', '군경할인', '크리스마스R석', '크리스마스S석', '난타 [S석]',
#        '3인 관람권(1인 가격)', '4인 관람권(1인 가격)', '특별할인가', '장애인/국가유공자 할인(본인만)',
#        '재관람 할인(1인1매)', 'R석 장애인,국가유공자할인(동반1인)', 'R석 수험생할인(1인2매)',
#        'R석 헬로 모디', 'S석 재관람카드 50% 할인권(1인1매)', '국가유공자할인(1인1매)',
#        '컴프롬쇼노트 할인(1인4매)', '신용카드사', '크리스마스(이브)할인', '크리스마스이브할인',
#        '크리스마스 이브 할인', '메리크리스마스', '공무원, 50세 이상 할인', '소설출간기념 공연할인', 'B석 정가',
#        'VIP석 재관람할인(2023~24년 유료,1인1매)', 'A석 정가',
#        'B석 재관람할인(2023~24년 유료,1인1매)', 'R석 재관람할인(2023~24년 유료,1인1매)',
#        'S석 재관람할인(2023~24년 유료,1인1매)', 'VIP석 국가유공자할인(본인만)',
#        '재관람 할인(1인2매)30%', '대학생 할인(본인만)30%', '청소년 할인(본인만)30%',
#        '멤버쉽50%할인권(본인만)', '멤버쉽90%할인권(본인만)', '크리스마스 일반', '난타[VIP석]',
#        '1차얼리버드할인_할인정보확인', '2차얼리버드할인_할인정보확인', '성인할인', '청소년,어린이할인',
#        '3인관람권_3명관람 시 적용', '4인관람권_4명관람 시 적용', '[문화데이] 뮤지컬, 콘서트, 클래식 쿠폰',
#        '난타[S석]', '[문화데이] 연극/대학로, 전시/체험, 키즈 쿠폰', '마지막 조기 예매 할인',
#        '복지 할인 4~6급', '굿바이 타임세일', '3인 패키지 할인', '재관람 할인(2023~24년 유료,1인1매)',
#        'BC카드', '복지 할인(본인만)', '재관람 할인(본인만)', '4인 패키지', '3인 패키지',
#        '장애인 1~3급 (중증)', '장애인 4~6급 (경증)', 'Adue 2023 & Happy new Year!',
#        '초특가 이벤트', 'R석 플라워노트 40%할인권 소지자(1인1매)', 'R석 재관람 할인(1인1매)',
#        'R석 2차 조기예매 할인', 'R석 청소년 할인(본인만)', 'R석 우리 함께 춤을 추는거야',
#        '전석_크리스마스할인', '다중할인', 'OP석 정가', 'OP석 재관람할인(1인1매)',
#        'OP석 장애인할인(4~6급,경증/1인1매)', 'R석 장애인할인(4~6급,경증/1인1매)',
#        'VIP석 장애인할인(4~6급,경증/1인1매)', 'S석 청소년할인(초,중,고/1인1매)',
#        'VIP석 컴프롬쇼노트 할인(1인4매)', 'S석 컴프롬쇼노트 할인(1인4매)', '[레베카] 시크릿 쿠폰',
#        '조기예매(11/16까지) 10%', '장애인4~6급(경증/본인) 20%', '장애인1~3급(중증/동반1인) 20%',
#        '패밀리할인 10%', 'BC카드할인', '재관람할인(2023~24년 유료,1인1매)',
#        '재관람 할인(미공개 스틸컷 포스터북 증정)', '장애인 할인(경증, 4~6급/본인한정)', '조기예매',
#        '[플레이위크] 할인쿠폰', '[플레이위크] 스페셜쿠폰(12/4)', '다시 맨덜리로', '장애인4~6급(본인만)',
#        '초중고생 할인(본인만)', '국가유공자(본인만)', '장애인1~3급(동반1인까지)', 'LIFECARE 복지몰',
#        'R석 3차 조기예매', 'S석 재관람(지난유료티켓 소지자)', 'S석 청소년(2005년~2007년 출생자)',
#        'R석 재관람(지난유료티켓 소지자)', 'BC 카드회원', 'S석 조기예매할인', 'A석 4인이상할인',
#        'R석 장애인할인(4~6급,경증/본인만)', 'A석 직장인할인(본인만)', '크리스마스 관람가',
#        '12월15일까지예매시할인권', '크리스마스공연관람권', '연극+음료+음식(안주) 1인', '연극+음료 1매',
#        '연극관람권 1매', '연극+음료+1인음식 1매', '2호선 정가', '주말 할인(일반)', '예술인관계자',
#        '성북구민', '파트너 할인', '장애인국가유공자', '학생/청소년', '일반할인', '굿바이 2023',
#        '[12월 공연티켓 연말쿠폰] 신한카드', '전석 주말할인', '전석 정가', '일반예매', '4인관람권',
#        '청소년권', '조기예매(1인 2매)', 'S석(네이버 특가 30%)', '연인할인', '학생할인(초/중/고/대학생)',
#        '배우할인', '소방공무원할인', '프렌즈할인', '장애인/국가유공자/예술인할인', '크리스마스시즌 관람가',
#        '[W공연티켓] 삼성카드', '지인할인석', '4인석 R석', '3인석 R석', '특별할인(R석)',
#        '4인석 특별할인(R석)', '크리스마스할인1인가', '조기예매 할인', 'sns팔로우할인',
#        '친한친구(유료회원)40%', '문화누리카드소지자50%_본인만', '<조씨고아...>재관람20%_명동예술극장공연',
#        '대학생및청소년40%', '푸른티켓_본인만', '문화릴레이티켓20%', '경로(65세이상)50%', '임산부20%',
#        '예술인패스소지자30%', '조씨고아,복수의씨앗_내부관계자50%', '2024학년도수능생40%',
#        '신규회원 20%할인쿠폰', '국립극단연극인회원50%_본인만', '장애인50%', '북클럽문학동네회원30%_본인만',
#        '조씨고아, 복수의 씨앗_내부관계자50%', '예술인패스', 'ARKO 일반회원', '패키지티켓', '파트너할인',
#        'ARKO 공연예술인회원', '예비작가할인', 'ARKO 매니아회원', '문화누리카드', '삼국지 할인(본인만)',
#        'R석(네이버 특가 30%)', '크리스마스 타임할인', '모든날모든순간 정가', '2인 예매권', '초등학생',
#        '대학생', '성인 1인', '2차 크리스마스 할인', 'CK아트홀 채널추가이벤트', '문화 협약 기업 할인',
#        '55%할인권소지자', '상시할인', '50% 할인권 소지자', '극단 산수유 매니아', '대학생할인', 'SNS할인',
#        '서울연극협회회원', '조기예매 40%', '장애인 / 유공자 50%', '엔톡(NTOK)회원 20%',
#        '수험생 할인 40%', '삼국지 할인 20%', '전석 국가유공자(본인)', '전석 청소년(본인)',
#        '전석 장애인(4~6급,경증/본인만)', '전석 장애인(1~3급,중증/동반1인)', '전석 유료티켓 소지자할인',
#        '조기예매 할인30%(주말)', '중년 할인', '실버 할인', '가족할인(2인)', 'SNS 팔로우 할인',
#        '문디&땅쇠 2인 패키지권', '시니어 할인', '어댑터 인친 할인', '사전예약 할인', '어댑터 마니아 할인',
#        '주말 할인', '대딩 할인', '예술인 할인', '[12월 공연티켓 연말쿠폰] 하나카드',
#        '카카오채널1차 open이벤트', '차비할인', '제휴매장 할인', '카카오톡채널추가할인', '전북현대자동차 직원할인',
#        '커플.부부할인', '크리스마스연휴고정할인', '실버할인', '파워제휴할인', '국가유공자할인', '장애인(4-6급)',
#        '복지할인_동반1인(현장확인)', 'R석 청소년할인(1인1매)', 'R석 재관람카드 40% 할인권(1인1매)',
#        'R석 에곤 하이', '패키지 정상가', '크리스마스할인_1차', '크리스마스할인_2차', '크리스마스할인_3차',
#        'S석 크리스마스 사전예매', 'S석 크리스마스할인', '크리스마스2인권', '네이버할인', '예술나눔 회원',
#        '일반 및 청소년 30% 할인', '일반/청소년', 'X-mas 이벤트 할인+할인', '연극인할인',
#        '크리스마스티켓3', '배우스탭지인', '학생', '영등포구 주민', '예술인', '크리스마스 할인 1인',
#        '온라인예매할인', '카카오채널할인', '예술인패스할인', '청소년할인', '장애인/국가유공자할인',
#        'N차관람할인(5회/본인만)', 'N차관람할인(4회/본인만)', '사전예약 (17일까지)', '디너쇼',
#        '1인 주말/공휴일 관람권', 'VIP석(4인)-가족패키지', 'VIP석(3인)-가족패키지',
#        '제주도민할인(본인에한함)', 'X-mas 할인(일반예매)', '크리스마스공연(4인)관람권', '팔로우 할인-주말',
#        '해녀 다이닝_디너', '홀수 좌석 예매', '뷰티풀라이프', '58년생부터 실버할인', '사전예매 할인 VIP석',
#        '초,중,고 학생할인 VIP석', '만65세이상 할인 VIP석', '유아(미취학) 할인 VIP석',
#        '국가유공자,장애우할인VIP석', '크리스마스 당일 특가', '[플레이위크] 스페셜쿠폰(12/9)',
#        '네이버예약 R석 30%', '네이버예약 S석 40%', '크리스마스 1차 얼리버드.', '크리스마스 2차 얼리버드.',
#        '크리스마스 티켓1', '크리스마스특별할인40%', '예술인 할인(본인만)30%', '단체 할인(10매 이상)',
#        '저세상텐션석', 'COUPON', '주말할인', '화상 할인', '중증장애인 본인과 동행하는 보호자 1인',
#        '플라워노트 40%할인권 소지자(1인1매)', '4인 패키지 할인', '40% 할인권 소지자',
#        'R석 독립유공자 할인(1인2매)', '시야제한석 플라워노트 40%할인권 소지자(1인1매)', 'R석 N321 할인',
#        'S석 가족할인', '연극+음료 1인', 'S석 3차 조기예매', '장애인(1-3급)', '재관람할인(1인1매)',
#        'VIP석 재관람할인(1인1매)', 'S석 재관람할인(1인1매)', '크리스마스단독특가(비지정석)',
#        '크리스마스 가격', '크리마스시즌할인', '사전예매할인. 23일까지', '생일할인', '예술인할인',
#        '4인권 특별할인', '[몬테크리스토] 2차 관람 쿠폰', '수능끝할인시작!!', '재관람', '장애인(본인)',
#        '초중고생', '국가유공자 할인(본인한정)', '수험생할인(실물2024년수능수험표소지자/1인2매)',
#        '크리스마스 심야할인 특가', 'R석 재관람카드 50% 할인권(1인1매)', 'N차관람할인(3회/본인만)',
#        'choice석', 'alive 석', '주말/공휴일 심야할인', '[크리스마스] 3차 얼리버드',
#        '[크리스마스] 선착순 할인', '심야할인', '성탄전야', '재관람 할인'], dtype=object)

# %%
lst=[
       '고양문화재단회원 10,000원', '재관람할인', '컴프롬쇼노트 할인', 'R석 재관람할인(1인1매)',
       '재관람할인(본인만)','R석 미드나잇 마니아 할인(본인만)',
       'R석 재관람 할인(본인만)',  'BNK 전용할인','엔톡(NTOK)회원 10%', '예술인패스카드 30%',
       '파크컴퍼니 매니아 20%',
       'VIP석 〈마리 퀴리〉 재관람 할인(1인1매)', 'R석 실험노트50%할인권소지자할인(1인1매)',
       '재관람 할인 (실물 유료 티켓  소지자 할인)',  '[몬테크리스토] 1차 관람 쿠폰',
       '재관람 할인(1인1매)',
       'S석 재관람카드 50% 할인권(1인1매)',
       '컴프롬쇼노트 할인(1인4매)',
       'VIP석 재관람할인(2023~24년 유료,1인1매)',
       'B석 재관람할인(2023~24년 유료,1인1매)', 'R석 재관람할인(2023~24년 유료,1인1매)',
       'S석 재관람할인(2023~24년 유료,1인1매)',
       '재관람 할인(1인2매)30%',
       '멤버쉽50%할인권(본인만)',  '재관람 할인(2023~24년 유료,1인1매)',
        '재관람 할인(본인만)', 'R석 재관람 할인(1인1매)',
        'OP석 재관람할인(1인1매)','재관람할인(2023~24년 유료,1인1매)',
       '재관람 할인(미공개 스틸컷 포스터북 증정)', '다시 맨덜리로',  'S석 재관람(지난유료티켓 소지자)',
       'R석 재관람(지난유료티켓 소지자)', '예술인관계자',
       '문화누리카드소지자50%_본인만', '<조씨고아...>재관람20%_명동예술극장공연',
       '예술인패스소지자30%', '조씨고아,복수의씨앗_내부관계자50%', '국립극단연극인회원50%_본인만',
       '조씨고아, 복수의 씨앗_내부관계자50%', '예술인패스', 'ARKO 일반회원',
       'ARKO 공연예술인회원', 'ARKO 매니아회원', '극단 산수유 매니아',
       '서울연극협회회원', '엔톡(NTOK)회원 20%','전석 유료티켓 소지자할인',
        '어댑터 마니아 할인','예술인 할인',  'R석 재관람카드 40% 할인권(1인1매)', '예술나눔 회원',
      '연극인할인','예술인패스할인',
       'N차관람할인(5회/본인만)', 'N차관람할인(4회/본인만)', '예술인 할인(본인만)30%',
       '플라워노트 40%할인권 소지자(1인1매)', '시야제한석 플라워노트 40%할인권 소지자(1인1매)', '재관람할인(1인1매)',
       'VIP석 재관람할인(1인1매)', 'S석 재관람할인(1인1매)', '예술인할인',
        '[몬테크리스토] 2차 관람 쿠폰', '재관람', 'R석 재관람카드 50% 할인권(1인1매)', 'N차관람할인(3회/본인만)',
       '재관람 할인']

# '할인종류명(전송처)'이 lst에 있으면 '재관람' 칼럼에 1을, 아니면 0을 부여
df['재관람'] = df['할인종류명(전송처)'].apply(lambda x: 1 if x in lst else 0)

# 결과 확인
df['재관람'].value_counts()
# Out:
# 재관람
# 0    93981
# 1      735
# Name: count, dtype: int64

# %% [markdown]
# ## 조기예매 여부 칼럼

# %% [markdown]
# 1) 데이터 필터링
#
# 2) 새로운 파생변수 조기예매 여부: 조기예매면 1, 아니면 0
#
# abs(예매취소일시 - 판매시작일시) = 10

# %%
df['판매시작일시'].head()
# Out:
# 0     2023/11/24 11:13:53
# 1     2023/11/24 11:13:53
# 11    2023/11/06 09:00:00
# 12    2023/11/06 09:00:00
# 13    2023/11/06 09:00:00
# Name: 판매시작일시, dtype: object

# %%
# 1. 판매시작일시 열이 문자열이 아닌 경우, 문자열로 변환
df['판매시작일시'] = df['판매시작일시'].astype(str)

# 2. 결측치 처리: 판매시작일시가 9999년, 2099년, 2021년인 경우 NaT로 처리
df.loc[df['판매시작일시'].str[:4].isin(['9999', '2099', '2021']), '판매시작일시'] = pd.NaT

# 3. 판매시작일시와 예매/취소일시를 datetime 형식으로 변환
df['판매시작일시'] = pd.to_datetime(df['판매시작일시'], errors='coerce')
df['예매/취소일시'] = pd.to_datetime(df['예매/취소일시'], errors='coerce')

# 4. 조기예매 판정: 예매/취소일시와 판매시작일시의 차이가 10일 이하인 경우 1, 그렇지 않으면 0
df['조기예매'] = (df['예매/취소일시'] - df['판매시작일시']).dt.days <= 10

# True/False 값을 1/0으로 변환
df['조기예매'] = df['조기예매'].astype(int)

# 결과 확인
print(df['조기예매'].value_counts())
# Out:
# 조기예매
# 0    56737
# 1    37979
# Name: count, dtype: int64

# %%
# 데이터 다운로드
df.to_excel("/content/drive/MyDrive/KOPIS공모전/데이터/EDA용 데이터/20231224.xlsx",
            index=False)

# %% [markdown]
# ## 연극/뮤지컬 데이터 분리

# %%
df['장르명'].value_counts()
# Out:
# 장르명
# 뮤지컬    60236
# 연극     34480
# Name: count, dtype: int64

# %%
df_play = df[df['장르명']=='연극']
df_musical= df[df['장르명']=='뮤지컬']

# %% [markdown]
# # EDA_연극

# %% [markdown]
# ### 공연코드

# %%
df_play['공연코드'].value_counts()
# Out:
# 공연코드
# PF394750    1102
# PF343804    1039
# PF440457    1031
# PF392163     999
# PF437423     872
#             ...
# PF454703       2
# PF452813       2
# PF453834       2
# PF452750       1
# PF454062       1
# Name: count, Length: 151, dtype: int64

# %% [markdown]
# ### 공연일시에 따른 가격

# %%
df_play['공연일시']=pd.to_datetime(df_play['공연일시'])

# 시각화: 공연일시별 평균 장당금액 변화
mean_price = df_play.groupby('공연일시')['장당금액'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(x='공연일시', y='장당금액', data=mean_price, marker='o')
plt.title('Ticket Price by Performance Time')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-161-8228dca8b27c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_play['공연일시']=pd.to_datetime(df_play['공연일시'])

# %% [markdown]
# ### 예매/취소매수

# %%
df_play['예매/취소매수'].value_counts()
# Out:
# 예매/취소매수
# 1    34480
# Name: count, dtype: int64

# %% [markdown]
# ### 예매/취소 금액

# %%
df_play['예매/취소금액'].value_counts()
# Out:
# 예매/취소금액
# 35000     3895
# 30000     3771
# 25000     3400
# 40000     2439
# 36000     1834
#           ...
# 5990         1
# 120000       1
# 23230        1
# 16800        1
# 21900        1
# Name: count, Length: 166, dtype: int64

# %%
df_play['예매/취소금액'].value_counts().sort_index(ascending=False)
# Out:
# 예매/취소금액
# 131600    26
# 120000     1
# 115000     4
# 111600    26
# 101700    20
#           ..
# 8000       8
# 7900      12
# 5990       1
# 5000       3
# 0         93
# Name: count, Length: 166, dtype: int64

# %%
# 예매취소금액 분포
# 예매취소금액이 0인 것은 결측치로 처리하고 제거

df_play_price=df_play[df_play['예매/취소금액']!=0]

# 시각화: 금액 분포 박스 플롯
plt.figure(figsize=(8, 6))
sns.boxplot(y='예매/취소금액', data=df_play_price, showfliers=False)
plt.show()

# 시각화: 금액 분포 히스토그램
plt.figure(figsize=(8, 6))
sns.histplot(df_play_price['예매/취소금액'], kde=True)
plt.show()

# %%
# 시각화: 공연일시별 평균 예매금액 변화
mean_price = df_play_price.groupby('공연일시')['예매/취소금액'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(x='공연일시', y='예매/취소금액', data=mean_price, marker='o')
plt.title('Ticket Price by Performance Time')
plt.xticks(rotation=45)
plt.show()

# %%
# 재관람과 비재관람 데이터의 예매/취소 금액 차이

# 박스 플롯 시각화: 재관람 여부에 따른 예매/취소금액 비교
plt.figure(figsize=(10, 6))
sns.boxplot(x='재관람', y='예매/취소금액', data=df_play)
plt.title('Comparison of price by reviewing')
plt.xlabel('Review (0: non, 1: re)')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ### 예매/취소방식명

# %%
df_play['예매/취소방식명(관리시스템)'].value_counts()
# Out:
# 예매/취소방식명(관리시스템)
# 모바일    27242
# 웹       7238
# Name: count, dtype: int64

# %%
# 장당금액 웹 vs 모바일
plt.figure(figsize=(10, 6))
sns.boxplot(x='예매/취소방식명(관리시스템)', y='장당금액', data=df_play)
plt.xlabel('Web vs Mobile')
plt.ylabel('A ticket Price')
plt.show()

# %%
# 할인금액 웹 vs 모바일
# 시각화: 웹 vs 모바일 장당금액 비교 (박스 플롯)
plt.figure(figsize=(10, 6))
sns.boxplot(x='예매/취소방식명(관리시스템)', y='할인금액', data=df_play)
plt.xlabel('Web vs Mobile')
plt.ylabel('Price')
plt.show()

# %%
# 할인금액의 분포를 히스토그램으로 시각화 (웹 vs 모바일)
plt.figure(figsize=(10, 6))
sns.histplot(data=df_play, x='할인금액', hue='예매/취소방식명(관리시스템)', kde=True, multiple='stack')
plt.title('Discount Distn: Web vs Mobile')
plt.xlabel('Discount')
plt.ylabel('Freq')
plt.show()

# %%
# 구매처 별 재관람 건수 시각화
revisit_ratio = df_play.groupby('예매/취소방식명(관리시스템)')['재관람'].sum().reset_index()

# 바 그래프 시각화
plt.figure(figsize=(8, 6))
sns.barplot(x='예매/취소방식명(관리시스템)', y='재관람', data=revisit_ratio)
plt.title('Review Events by Web vs Mobile')
plt.xlabel('Web vs Mobile')
plt.ylabel('Review')
plt.show()

# %%
# 예매방식명별로 재관람 비율 계산
# 재관람의 비율은 '재관람' 값이 1인 경우의 평균으로 계산할 수 있습니다.
revisit_ratio = df_play.groupby('예매/취소방식명(관리시스템)')['재관람'].mean().reset_index()

# 바 그래프 시각화
plt.figure(figsize=(8, 6))
sns.barplot(x='예매/취소방식명(관리시스템)', y='재관람', data=revisit_ratio)
plt.title('웹 vs 모바일 재관람 비율 비교')
plt.xlabel('예매 방식')
plt.ylabel('재관람 비율')
plt.ylim(0, 0.1)
plt.show()

# %% [markdown]
# ### 성별

# %% [markdown]
# 1: 남, 2: 여, 0: 알수없음

# %%
df_play['성별'].value_counts()
# Out:
# 성별
# 2    16960
# 1    12309
# 0     5211
# Name: count, dtype: int64

# %%
# 성별 웹 vs 모바일

# 성별 및 예매/취소방식명(관리시스템)별 빈도 계산
gender_distribution = df_play.groupby(['예매/취소방식명(관리시스템)', '성별']).size().reset_index(name='count')

# 시각화: 웹 vs 모바일 성별 분포 바 그래프
plt.figure(figsize=(10, 6))
sns.barplot(x='예매/취소방식명(관리시스템)', y='count', hue='성별', data=gender_distribution)
plt.title('Gender Distribution: Web vs Mobile')
plt.xlabel('Web vs Mobile')
plt.ylabel('Gender')
plt.legend(title='gender', labels=['0','1', '2'])  # 성별에 맞는 레이블 설정
plt.show()

# %%
# 성별 별 예매금액의 차이

# 1. 성별 값이 0인 데이터를 제거 (0은 결측치로 간주)
df_filtered = df_play[df_play['성별'] != 0]

plt.figure(figsize=(10, 6))
sns.violinplot(x='성별', y='예매/취소금액', data=df_filtered)
plt.title('Price Comparison by Gender (Violin Plot)')
plt.xlabel('Gender (1: Men, 2: Women)')
plt.ylabel('Prices')
plt.xticks(ticks=[0, 1], labels=['Men', 'Women'])  # 성별 레이블 설정
plt.show()

# %%
# 성별 별 장당금액의 차이
# 1. 성별 값이 0인 데이터를 제거 (0은 결측치로 간주)
df_filtered = df_play[df_play['성별'] != 0]

plt.figure(figsize=(10, 6))
sns.violinplot(x='성별', y='장당금액', data=df_filtered)
plt.title('Ticket Price Comparison by Gender (Violin Plot)')
plt.xlabel('Gender (1: Men, 2: Women)')
plt.ylabel('Prices')
plt.xticks(ticks=[0, 1], labels=['Men', 'Women'])  # 성별 레이블 설정
plt.show()

# %%
# 성별 별 극장 규모의 차이

df_filtered = df_play[df_play['성별'] != 0]

# 2. 성별별 극장 규모 분포를 시각화 (countplot 사용)
plt.figure(figsize=(10, 6))
sns.countplot(x='극장규모', hue='성별', data=df_filtered)
plt.title('Theatre Scale by Gender')
plt.xlabel('Theatre scale (0: Small, 1: Medium, 2: Large)')
plt.ylabel('Freq')
plt.xticks(ticks=[0, 1, 2], labels=['Small', 'Medium', 'Large'])
plt.legend(title='gender', labels=['Men', 'Women'])
plt.show()

# %%
# 성별 별 재관람율의 차이
# 1. 성별 값이 0인 데이터를 제거 (0은 결측치로 간주)
df_filtered = df_play[df_play['성별'] != 0]

# 2. 성별별 재관람율 계산
total_counts_by_gender = df_filtered.groupby('성별')['재관람'].count().reset_index(name='총예매수')
revisit_counts_by_gender = df_filtered.groupby('성별')['재관람'].sum().reset_index(name='재관람수')

# 3. 재관람율 계산 (재관람수 / 총예매수)
revisit_ratio_by_gender = pd.merge(revisit_counts_by_gender, total_counts_by_gender, on='성별')
revisit_ratio_by_gender['재관람율'] = revisit_ratio_by_gender['재관람수'] / revisit_ratio_by_gender['총예매수']

# 4. 바 그래프 시각화
plt.figure(figsize=(8, 6))
plt.bar(revisit_ratio_by_gender['성별'].map({1: 'Men', 2: 'Women'}), revisit_ratio_by_gender['재관람율'])
plt.title('Review Proportion Comparison by Gender')
plt.xlabel('gender')
plt.ylabel('Review')
plt.ylim(0, 0.1)  # 비율이므로 y축 범위를 0에서 1로 설정

# 그래프 표시
plt.show()

# %% [markdown]
# ### 연령

# %%
# 1. 연령이 (0, 100) 사이가 아닌건 이상치로 처리하고 제거
df_filtered = df_play[(df_play['연령'] >= 0) & (df_play['연령'] < 100)]

# 2. 연령 분포 시각화 (히스토그램)
plt.figure(figsize=(10, 6))
sns.histplot(df_filtered['연령'], bins=30, kde=True)
plt.title('Age Distn')
plt.xlabel('Age')
plt.ylabel('Freq')
plt.show()

# %%
# 성별 별 연령분포
df_filtered = df_play[df_play['성별'] != 0]

# 2. 연령 분포 시각화 (히스토그램)
plt.figure(figsize=(10, 6))
sns.histplot(data=df_filtered, x='연령', hue='성별', bins=30, kde=True, multiple='stack')
plt.title('Age Distn by Gender')
plt.xlabel('Age')
plt.ylabel('Freq')
plt.legend(title='gender', labels=['M', 'W'])
plt.show()

# %%
# 재관람 여부 별 연령 분포의 차이
df_filtered= df_play[(df_play['연령'] >= 0) & (df_play['연령'] < 100)]
plt.figure(figsize=(10, 6))
sns.histplot(data=df_filtered, x='연령', hue='재관람', bins=30, kde=True, multiple='stack')
plt.title('Age distn by reviewing')
plt.xlabel('Age')
plt.ylabel('Freq')
plt.legend(title='Review', labels=['re', 'non'])
plt.show()

# %%
# 1. 재관람 여부 별 연령 분포 시각화 (박스 플롯)
plt.figure(figsize=(10, 6))
sns.boxplot(x='재관람', y='연령', data=df_filtered)
plt.xlabel('Reviewing (0: non, 1: re)')
plt.ylabel('Age')
plt.xticks(ticks=[0, 1], labels=['non', 're'])
plt.show()

# %%
# 연령 별 극장 규모 차이

# 1. 연령 별 극장 규모 시각화 (박스 플롯)
plt.figure(figsize=(10, 6))
sns.boxplot(x='극장규모', y='연령', data=df_filtered)
plt.title('연령 별 극장 규모 차이 (박스 플롯)')
plt.xlabel('극장 규모 (0: 소극장, 1: 중극장, 2: 대극장)')
plt.ylabel('연령')
plt.xticks(ticks=[0, 1, 2], labels=['소극장', '중극장', '대극장'])
plt.show()

# 2. 연령 별 극장 규모 시각화 (바이올린 플롯)
plt.figure(figsize=(10, 6))
sns.violinplot(x='극장규모', y='연령', data=df_filtered)
plt.title('연령 별 극장 규모 차이 (바이올린 플롯)')
plt.xlabel('극장 규모 (0: 소극장, 1: 중극장, 2: 대극장)')
plt.ylabel('연령')
plt.xticks(ticks=[0, 1, 2], labels=['소극장', '중극장', '대극장'])
plt.show()

# %% [markdown]
# ### 공연지역명

# %%
df_play['공연지역명'].value_counts()
# Out:
# 공연지역명
# 서울     21735
# 경상도     5240
# 전라도     3288
# 충청도     3038
# 경기도      998
# 제주도      138
# 강원도       43
# Name: count, dtype: int64

# %%
# 공연지역명 별 극장 규모 조회
df_play.groupby('공연지역명')['극장규모'].value_counts()
# Out:
# 공연지역명  극장규모
# 강원도    0          43
# 경기도    2         663
#        1         321
#        0          14
# 경상도    1        3716
#        2        1126
#        0         398
# 서울     1       17240
#        2        2272
#        0        2223
# 전라도    1        1923
#        2        1351
#        0          14
# 제주도    0         138
# 충청도    1        1238
#        2        1112
#        0         688
# Name: count, dtype: int64

# %%
# 공연 지역명 별 장당 가격 비교
# 공연지역명 별 극장 규모 조회
df_play.groupby('공연지역명')['장당금액'].mean()
# Out:
# 공연지역명
# 강원도    15930.232558
# 경기도    31519.038076
# 경상도    37214.599237
# 서울     40534.499655
# 전라도    36652.068127
# 제주도    69724.637681
# 충청도    37188.775510
# Name: 장당금액, dtype: float64

# %%
# 공연 지역 별 재관람율 비교
df_play.groupby('공연지역명')['재관람'].mean()
# Out:
# 공연지역명
# 강원도    0.000000
# 경기도    0.014028
# 경상도    0.002099
# 서울     0.010766
# 전라도    0.000000
# 제주도    0.000000
# 충청도    0.000658
# Name: 재관람, dtype: float64

# %%
# 공연 지역 별 재관람율 비교
df_play.groupby('공연지역명')['재관람'].sum()
# Out:
# 공연지역명
# 강원도      0
# 경기도     14
# 경상도     11
# 서울     234
# 전라도      0
# 제주도      0
# 충청도      2
# Name: 재관람, dtype: int64

# %% [markdown]
# ### 내한공연 여부

# %%
df_play['내한공연 여부'].value_counts()
# Out:
# 내한공연 여부
# N    34480
# Name: count, dtype: int64

# %% [markdown]
# ### 오픈런 여부

# %%
df_play['오픈런 여부'].value_counts()
# Out:
# 오픈런 여부
# N    18659
# Y    15821
# Name: count, dtype: int64

# %%
# 오픈런 여부 별 장당 금액 비교
df_play.groupby('오픈런 여부')['장당금액'].mean()
# Out:
# 오픈런 여부
# N    38889.836004
# Y    39544.333481
# Name: 장당금액, dtype: float64

# %%
# 오픈런 여부 별 박스플롯
sns.boxplot(x='오픈런 여부', y='장당금액', data=df_play)
plt.title('Prices of Open Run')
plt.xlabel('Open run O X')
plt.ylabel('Prices')
plt.show()

# %%
# 오픈런 여부 별 극장규모 비교
df_play.groupby('오픈런 여부')['극장규모'].value_counts()
# Out:
# 오픈런 여부  극장규모
# N       1       10616
#         2        6524
#         0        1519
# Y       1       13822
#         0        1999
# Name: count, dtype: int64

# %%
# 오픈런 여부 별 재관람율 비교
df_play.groupby('오픈런 여부')['재관람'].mean()
# Out:
# 오픈런 여부
# N    0.012862
# Y    0.001327
# Name: 재관람, dtype: float64

# %%
df_play.groupby('오픈런 여부')['재관람'].sum()
# Out:
# 오픈런 여부
# N    240
# Y     21
# Name: 재관람, dtype: int64

# %% [markdown]
# ### 조기예매

# %%
# 조기예매 별 예매 금액 비교
df_play.groupby('조기예매')['예매/취소금액'].mean()
# Out:
# 조기예매
# 0    32471.289154
# 1    33874.335484
# Name: 예매/취소금액, dtype: float64

# %%
# 조기예매 별 예매 금액 박스플롯
sns.boxplot(x='조기예매', y='예매/취소금액', data=df_play)
plt.title('Prices of Early Buying')
plt.xlabel('Early Buying O X')
plt.ylabel('Prices')
plt.show()

# %%
# 조기예매 별 성별 분포 비교
df_play.groupby('조기예매')['성별'].value_counts()
# Out:
# 조기예매  성별
# 0     2     11946
#       1      9218
#       0      4791
# 1     2      5014
#       1      3091
#       0       420
# Name: count, dtype: int64

# %%
# 빈도수 계산
df_counts = df_play.groupby(['조기예매', '성별']).size().reset_index(name='count')

# 막대 그래프 그리기
sns.barplot(x='조기예매', y='count', hue='성별', data=df_counts)
plt.title('Gender Distn by Early Buying')
plt.xlabel('Early buying')
plt.ylabel('Freq')
plt.show()

# %%
# 조기 예매 별 예매처 비교
df_play.groupby('조기예매')['예매/취소방식명(관리시스템)'].value_counts()
# Out:
# 조기예매  예매/취소방식명(관리시스템)
# 0     모바일                20813
#       웹                   5142
# 1     모바일                 6429
#       웹                   2096
# Name: count, dtype: int64

# %%
# 빈도수 계산
df_counts = df_play.groupby(['조기예매', '예매/취소방식명(관리시스템)']).size().reset_index(name='count')

# 막대 그래프 그리기
sns.barplot(x='조기예매', y='count', hue='예매/취소방식명(관리시스템)', data=df_counts)
plt.title('Way Distn by Early Buying')
plt.xlabel('Early buying')
plt.ylabel('Freq')
plt.show()

# %% [markdown]
# ### 좌석 등급

# %%
df_play['좌석등급'].value_counts()
# Out:
# 좌석등급
# 전석(40000)                          11704
# 전석(35000)                           8046
# 전석(50000)                           3443
# 전석(60000)                           1994
# 전석(30000)                           1617
# 전석(45000)                           1337
# R석(66000), S석(55000)                1132
# 전석(66000)                            633
# (1층)R석(44000), (2층)S석(34000)         580
# R석(40000), S석(30000)                 563
# 전석(55000)                            557
# R석(77000), S석(55000)                 544
# R석(60000), S석(45000), A석(30000)      516
# R석(40000), S석(35000)                 475
# R석(35000), S석(30000)                 341
# R석(60000), S석(45000)                 328
# R석(66000), S석(44000)                 298
# 전석(20000)                            108
# 전석(63000)                             92
# 전석(21000)                             66
# 전석(69000)                             46
# 전석(33000)                             17
# 전석(22000)                             16
# 전석(25000)                             10
# 전석(15000)                              9
# 전석(10000)                              8
# Name: count, dtype: int64

# %% [markdown]
# ### 스타배우 영향

# %%
lst=['최정원', '고준희', '신성록', '차승원', '진선규', '엄기준', '양지원', '나문희', '봉태규', '김선영', '김수미', '고두심', '염혜란',
     '문소리', '박정원', '박은석', '박해수', '박소담', '정성일', '지현준', '이순재', '신구', '홍승안', '정휘', '전성우', '박정복', '전동석',
     '강홍석', '조승우', '옥주현', '정선아', '민경아', '김선영', '최재림', '전미도', '카이', '김준수', '홍강호', '박효신', '박강현', '정성화', '규현',
     '박은태', '박성훈', '조정석', '김승우', '지창욱', '홍광호', '신영숙', '차지연', '지창욱', '한지상', '마이클리', '김소현', '박건형', '윤공주', '바다', '서범석', '아이비']

# 스타배우 칼럼 추가
# 스타배우 칼럼 추가
# 스타배우 칼럼 추가
df_play['스타배우'] = df_play['출연진내용'].apply(
    lambda x: 1 if isinstance(x, str) and any(actor in x.split(', ') for actor in lst) else 0
)

df_play['스타배우'].value_counts()
# Out:
# <ipython-input-204-366bdc049cd2>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_play['스타배우'] = df_play['출연진내용'].apply(
# 스타배우
# 0    33121
# 1     1359
# Name: count, dtype: int64

# %%
# 파워칼럼
# 파워 칼럼 계산: 장당금액 * 좌석 수
df_play['파워'] = df_play['장당금액'] * df_play['좌석수']

# 스타배우 사용 여부에 따라 데이터 나누기
power_with_stars = df_play[df_play['스타배우'] == 1]['파워']
power_without_stars = df_play[df_play['스타배우'] == 0]['파워']

# 시각화
plt.figure(figsize=(12, 6))

# 히스토그램
plt.subplot(1, 2, 1)
sns.histplot(power_with_stars, bins=10, color='blue', kde=True, label='Star', stat='density')
sns.histplot(power_without_stars, bins=10, color='orange', kde=True, label='Nonstar', stat='density')
plt.title('Power Distn (Histogram)')
plt.xlabel('Power')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# <ipython-input-205-fe00685e0a77>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_play['파워'] = df_play['장당금액'] * df_play['좌석수']
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
power_with_stars = df_play[df_play['스타배우'] == 1]['파워']
power_without_stars = df_play[df_play['스타배우'] == 0]['파워']

sns.boxplot(power_with_stars)
plt.title('Star Power')
plt.show()
sns.boxplot(power_without_stars)
plt.title('Nonstar Power')
plt.show()

# %% [markdown]
# # EDA_뮤지컬

# %% [markdown]
# ### 공연코드

# %%
df_musical['공연코드'].value_counts()
# Out:
# 공연코드
# PF452530    4861
# PF447753    4801
# PF449225    3856
# PF452759    3577
# PF449787    3502
#             ...
# PF422856      10
# PF441107       8
# PF454605       8
# PF452506       8
# PF455237       4
# Name: count, Length: 76, dtype: int64

# %% [markdown]
# ### 공연일시에 따른 가격

# %%
df_musical['공연일시']=pd.to_datetime(df_musical['공연일시'])

# 시각화: 공연일시별 평균 장당금액 변화
mean_price = df_musical.groupby('공연일시')['장당금액'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(x='공연일시', y='장당금액', data=mean_price, marker='o')
plt.title('Ticket Price by Performance Time')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-208-55ed5fc0e369>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_musical['공연일시']=pd.to_datetime(df_musical['공연일시'])

# %% [markdown]
# ### 예매/취소매수

# %%
df_musical['예매/취소매수'].value_counts()
# Out:
# 예매/취소매수
# 1    60236
# Name: count, dtype: int64

# %% [markdown]
# ### 예매/취소 금액

# %%
df_musical['예매/취소금액'].value_counts()
# Out:
# 예매/취소금액
# 170000    4197
# 140000    3836
# 121000    2891
# 160000    2485
# 150000    2475
#           ...
# 28130        1
# 36580        1
# 109000       1
# 32010        1
# 37000        1
# Name: count, Length: 221, dtype: int64

# %%
df_musical['예매/취소금액'].value_counts().sort_index(ascending=False)
# Out:
# 예매/취소금액
# 199950      38
# 190000    1161
# 180500     582
# 180000    1196
# 173800      12
#           ...
# 9610        30
# 9000         4
# 5000        45
# 4000       192
# 0          303
# Name: count, Length: 221, dtype: int64

# %%
# 예매취소금액 분포
# 예매취소금액이 0인 것은 결측치로 처리하고 제거

df_musical_price=df_musical[df_musical['예매/취소금액']!=0]

# 시각화: 금액 분포 박스 플롯
plt.figure(figsize=(8, 6))
sns.boxplot(y='예매/취소금액', data=df_musical_price, showfliers=False)
plt.show()

# 시각화: 금액 분포 히스토그램
plt.figure(figsize=(8, 6))
sns.histplot(df_musical_price['예매/취소금액'], kde=True)
plt.show()

# %%
# 시각화: 공연일시별 평균 예매금액 변화
mean_price = df_musical_price.groupby('공연일시')['예매/취소금액'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(x='공연일시', y='예매/취소금액', data=mean_price, marker='o')
plt.title('Ticket Price by Performance Time')
plt.xticks(rotation=45)
plt.show()

# %%
df_musical.groupby('재관람')['예매/취소금액'].describe()
# Out:
#        count           mean           std      min      25%       50%  \
# 재관람
# 0    59762.0  100699.629832  51049.991610      0.0  52800.0  110000.0
# 1      474.0  108759.704641  42302.117744  15000.0  81000.0  112000.0
#
#           75%       max
# 재관람
# 0    140000.0  199950.0
# 1    136000.0  171000.0

# %%
df_musical[df_musical['재관람']==1].shape
# Out:
# (474, 27)

# %%
# 재관람과 비재관람 데이터의 예매/취소 금액 차이

# 박스 플롯 시각화: 재관람 여부에 따른 예매/취소금액 비교
plt.figure(figsize=(10, 6))
sns.boxplot(x='재관람', y='예매/취소금액', data=df_musical, showfliers=True)
plt.title('Comparison of price by reviewing')
plt.xlabel('Review (0: non, 1: re)')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ### 예매/취소방식명

# %%
df_musical['예매/취소방식명(관리시스템)'].value_counts()
# Out:
# 예매/취소방식명(관리시스템)
# 모바일    37329
# 웹      22907
# Name: count, dtype: int64

# %%
# 장당금액 웹 vs 모바일
plt.figure(figsize=(10, 6))
sns.boxplot(x='예매/취소방식명(관리시스템)', y='장당금액', data=df_musical)
plt.xlabel('Web vs Mobile')
plt.ylabel('A ticket Price')
plt.show()

# %%
# 할인금액 웹 vs 모바일
# 시각화: 웹 vs 모바일 장당금액 비교 (박스 플롯)
plt.figure(figsize=(10, 6))
sns.boxplot(x='예매/취소방식명(관리시스템)', y='할인금액', data=df_musical, showfliers=False)
plt.xlabel('Web vs Mobile')
plt.ylabel('Price')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 할인금액의 분포를 히스토그램으로 시각화 (웹 vs 모바일)
plt.figure(figsize=(10, 6))
sns.histplot(data=df_musical, x='할인금액', hue='예매/취소방식명(관리시스템)', kde=True, multiple='stack')
plt.title('Discount Distn: Web vs Mobile')
plt.xlabel('Discount')
plt.ylabel('Freq')
plt.show()

# %%
# 구매처 별 재관람 건수 시각화
revisit_ratio = df_musical.groupby('예매/취소방식명(관리시스템)')['재관람'].sum().reset_index()

# 바 그래프 시각화
plt.figure(figsize=(8, 6))
sns.barplot(x='예매/취소방식명(관리시스템)', y='재관람', data=revisit_ratio)
plt.title('Review Events by Web vs Mobile')
plt.xlabel('Web vs Mobile')
plt.ylabel('Review')
plt.show()

# %%
# 예매방식명별로 재관람 비율 계산
# 재관람의 비율은 '재관람' 값이 1인 경우의 평균으로 계산할 수 있습니다.
revisit_ratio = df_musical.groupby('예매/취소방식명(관리시스템)')['재관람'].mean().reset_index()

# 바 그래프 시각화
plt.figure(figsize=(8, 6))
sns.barplot(x='예매/취소방식명(관리시스템)', y='재관람', data=revisit_ratio)
plt.title('웹 vs 모바일 재관람 비율 비교')
plt.xlabel('예매 방식')
plt.ylabel('재관람 비율')
plt.ylim(0, 0.1)
plt.show()

# %% [markdown]
# ### 성별

# %%
df_musical['성별'].value_counts()
# Out:
# 성별
# 2    36704
# 1    16531
# 0     7001
# Name: count, dtype: int64

# %%
# 성별 웹 vs 모바일

# 성별 및 예매/취소방식명(관리시스템)별 빈도 계산
gender_distribution = df_musical.groupby(['예매/취소방식명(관리시스템)', '성별']).size().reset_index(name='count')

# 시각화: 웹 vs 모바일 성별 분포 바 그래프
plt.figure(figsize=(10, 6))
sns.barplot(x='예매/취소방식명(관리시스템)', y='count', hue='성별', data=gender_distribution)
plt.title('Gender Distribution: Web vs Mobile')
plt.xlabel('Web vs Mobile')
plt.ylabel('Gender')
plt.legend(title='gender', labels=['0','1', '2'])  # 성별에 맞는 레이블 설정
plt.show()

# %%
# 성별 별 예매금액의 차이

# 1. 성별 값이 0인 데이터를 제거 (0은 결측치로 간주)
df_filtered = df_musical[df_musical['성별'] != 0]

plt.figure(figsize=(10, 6))
sns.violinplot(x='성별', y='예매/취소금액', data=df_filtered)
plt.title('Price Comparison by Gender (Violin Plot)')
plt.xlabel('Gender (1: Men, 2: Women)')
plt.ylabel('Prices')
plt.xticks(ticks=[0, 1], labels=['Men', 'Women'])  # 성별 레이블 설정
plt.show()

# %%
# 성별 별 장당금액의 차이
# 1. 성별 값이 0인 데이터를 제거 (0은 결측치로 간주)
df_filtered = df_musical[df_musical['성별'] != 0]

plt.figure(figsize=(10, 6))
sns.violinplot(x='성별', y='장당금액', data=df_filtered)
plt.title('Ticket Price Comparison by Gender (Violin Plot)')
plt.xlabel('Gender (1: Men, 2: Women)')
plt.ylabel('Prices')
plt.xticks(ticks=[0, 1], labels=['Men', 'Women'])  # 성별 레이블 설정
plt.show()

# %%
# 성별 별 극장 규모의 차이

df_filtered = df_musical[df_musical['성별'] != 0]

# 2. 성별별 극장 규모 분포를 시각화 (countplot 사용)
plt.figure(figsize=(10, 6))
sns.countplot(x='극장규모', hue='성별', data=df_filtered)
plt.title('Theatre Scale by Gender')
plt.xlabel('Theatre scale (0: Small, 1: Medium, 2: Large)')
plt.ylabel('Freq')
plt.xticks(ticks=[0, 1, 2], labels=['Small', 'Medium', 'Large'])
plt.legend(title='gender', labels=['Men', 'Women'])
plt.show()

# %%
# 성별 별 재관람율의 차이
# 1. 성별 값이 0인 데이터를 제거 (0은 결측치로 간주)
df_filtered = df_musical[df_musical['성별'] != 0]

# 2. 성별별 재관람율 계산
total_counts_by_gender = df_filtered.groupby('성별')['재관람'].count().reset_index(name='총예매수')
revisit_counts_by_gender = df_filtered.groupby('성별')['재관람'].sum().reset_index(name='재관람수')

# 3. 재관람율 계산 (재관람수 / 총예매수)
revisit_ratio_by_gender = pd.merge(revisit_counts_by_gender, total_counts_by_gender, on='성별')
revisit_ratio_by_gender['재관람율'] = revisit_ratio_by_gender['재관람수'] / revisit_ratio_by_gender['총예매수']

# 4. 바 그래프 시각화
plt.figure(figsize=(8, 6))
plt.bar(revisit_ratio_by_gender['성별'].map({1: 'Men', 2: 'Women'}), revisit_ratio_by_gender['재관람율'])
plt.title('Review Proportion Comparison by Gender')
plt.xlabel('gender')
plt.ylabel('Review')
plt.ylim(0, 0.1)  # 비율이므로 y축 범위를 0에서 1로 설정

# 그래프 표시
plt.show()

# %% [markdown]
# ### 연령

# %%
# 1. 연령이 (0, 100) 사이는 이상치로 처리하고 제거
df_filtered = df_musical[(df_musical['연령'] >= 0) & (df_musical['연령'] < 100)]

# 2. 연령 분포 시각화 (히스토그램)
plt.figure(figsize=(10, 6))
sns.histplot(df_filtered['연령'], bins=30, kde=True)
plt.title('Age Distn')
plt.xlabel('Age')
plt.ylabel('Freq')
plt.show()

# %%
# 성별 별 연령분포
df_filtered = df_musical[df_musical['성별'] != 0]

# 2. 연령 분포 시각화 (히스토그램)
plt.figure(figsize=(10, 6))
sns.histplot(data=df_filtered, x='연령', hue='성별', bins=30, kde=True, multiple='stack')
plt.title('Age Distn by Gender')
plt.xlabel('Age')
plt.ylabel('Freq')
plt.legend(title='gender', labels=['M', 'W'])
plt.show()

# %%
# 재관람 여부 별 연령 분포의 차이
df_filtered= df_musical[(df_musical['연령'] >= 0) & (df_musical['연령'] < 100)]
plt.figure(figsize=(10, 6))
sns.histplot(data=df_filtered, x='연령', hue='재관람', bins=30, kde=True, multiple='stack')
plt.title('Age distn by reviewing')
plt.xlabel('Age')
plt.ylabel('Freq')
plt.legend(title='Review', labels=['re', 'non'])
plt.show()

# %%
# 1. 재관람 여부 별 연령 분포 시각화 (박스 플롯)
plt.figure(figsize=(10, 6))
sns.boxplot(x='재관람', y='연령', data=df_filtered)
plt.xlabel('Reviewing (0: non, 1: re)')
plt.ylabel('Age')
plt.xticks(ticks=[0, 1], labels=['non', 're'])
plt.show()

# %%
# 연령 별 극장 규모 차이

# 1. 연령 별 극장 규모 시각화 (박스 플롯)
plt.figure(figsize=(10, 6))
sns.boxplot(x='극장규모', y='연령', data=df_filtered)
plt.title('연령 별 극장 규모 차이 (박스 플롯)')
plt.xlabel('극장 규모 (0: 소극장, 1: 중극장, 2: 대극장)')
plt.ylabel('연령')
plt.xticks(ticks=[0, 1, 2], labels=['소극장', '중극장', '대극장'])
plt.show()

# 2. 연령 별 극장 규모 시각화 (바이올린 플롯)
plt.figure(figsize=(10, 6))
sns.violinplot(x='극장규모', y='연령', data=df_filtered)
plt.title('연령 별 극장 규모 차이 (바이올린 플롯)')
plt.xlabel('극장 규모 (0: 소극장, 1: 중극장, 2: 대극장)')
plt.ylabel('연령')
plt.xticks(ticks=[0, 1, 2], labels=['소극장', '중극장', '대극장'])
plt.show()

# %% [markdown]
# ### 공연지역명

# %%
df_musical['공연지역명'].value_counts()
# Out:
# 공연지역명
# 서울     46232
# 경상도    10041
# 경기도     1785
# 충청도     1358
# 전라도      428
# 제주도      222
# 강원도      170
# Name: count, dtype: int64

# %%
# 공연지역명 별 극장 규모 조회
df_musical.groupby('공연지역명')['극장규모'].value_counts()
# Out:
# 공연지역명  극장규모
# 강원도    0         170
# 경기도    1        1023
#        2         744
#        0          18
# 경상도    2        9761
#        0         280
# 서울     2       24450
#        1       14392
#        0        7390
# 전라도    1         428
# 제주도    1         222
# 충청도    1         730
#        2         547
#        0          81
# Name: count, dtype: int64

# %%
# 공연 지역명 별 장당 가격 비교
# 공연지역명 별 극장 규모 조회
df_musical.groupby('공연지역명')['장당금액'].mean()
# Out:
# 공연지역명
# 강원도     47235.294118
# 경기도     77089.355742
# 경상도    121547.958371
# 서울     104078.892326
# 전라도     47021.028037
# 제주도     56779.279279
# 충청도     41436.229750
# Name: 장당금액, dtype: float64

# %%
# 공연 지역 별 재관람율 비교
df_musical.groupby('공연지역명')['재관람'].mean()
# Out:
# 공연지역명
# 강원도    0.000000
# 경기도    0.000000
# 경상도    0.011951
# 서울     0.007397
# 전라도    0.000000
# 제주도    0.000000
# 충청도    0.008837
# Name: 재관람, dtype: float64

# %%
# 공연 지역 별 재관람 비교
df_musical.groupby('공연지역명')['재관람'].sum()
# Out:
# 공연지역명
# 강원도      0
# 경기도      0
# 경상도    120
# 서울     342
# 전라도      0
# 제주도      0
# 충청도     12
# Name: 재관람, dtype: int64

# %% [markdown]
# ### 내한공연여부

# %%
df_musical['내한공연 여부'].value_counts()
# Out:
# 내한공연 여부
# N    57129
# Y     3107
# Name: count, dtype: int64

# %%
df_musical.groupby('내한공연 여부')['장당금액'].mean()
# Out:
# 내한공연 여부
# N    103152.645767
# Y    120330.157708
# Name: 장당금액, dtype: float64

# %%
# 박스플롯 시각화
plt.figure(figsize=(8, 6))
sns.boxplot(x='내한공연 여부', y='장당금액', data=df_musical, palette=["blue", "orange"])
plt.ylabel('Price')
plt.show()
# Out:
# <ipython-input-241-cda8f3e1639c>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='내한공연 여부', y='장당금액', data=df_musical, palette=["blue", "orange"])

# %%
# 내한공연 별 재관람 횟수 관찰
df_musical.groupby('내한공연 여부')['재관람'].sum()
# Out:
# 내한공연 여부
# N    419
# Y     55
# Name: 재관람, dtype: int64

# %%
# 내한공연 별 재관람율 관찰
df_musical.groupby('내한공연 여부')['재관람'].mean()
# Out:
# 내한공연 여부
# N    0.007334
# Y    0.017702
# Name: 재관람, dtype: float64

# %% [markdown]
# ### 오픈런 여부

# %%
df_musical['오픈런 여부'].value_counts()
# Out:
# 오픈런 여부
# N    57763
# Y     2473
# Name: count, dtype: int64

# %%
# 오픈런 여부 별 장당 금액 비교
df_musical.groupby('오픈런 여부')['장당금액'].mean()
# Out:
# 오픈런 여부
# N    106436.476637
# Y     48031.985443
# Name: 장당금액, dtype: float64

# %%
# 오픈런 여부 별 박스플롯
sns.boxplot(x='오픈런 여부', y='장당금액', data=df_musical)
plt.title('Prices of Open Run')
plt.xlabel('Open run O X')
plt.ylabel('Prices')
plt.show()

# %%
# 오픈런 여부 별 극장규모 비교
df_musical.groupby('오픈런 여부')['극장규모'].value_counts()
# Out:
# 오픈런 여부  극장규모
# N       2       35502
#         1       15626
#         0        6635
# Y       0        1304
#         1        1169
# Name: count, dtype: int64

# %%
# 오픈런 여부 별 재관람율 비교
df_musical.groupby('오픈런 여부')['재관람'].mean()
# Out:
# 오픈런 여부
# N    0.008102
# Y    0.002426
# Name: 재관람, dtype: float64

# %%
df_musical.groupby('오픈런 여부')['재관람'].sum()
# Out:
# 오픈런 여부
# N    468
# Y      6
# Name: 재관람, dtype: int64

# %% [markdown]
# ### 조기예매

# %%
# 조기예매 별 예매 금액 비교
df_musical.groupby('조기예매')['예매/취소금액'].mean()
# Out:
# 조기예매
# 0     96952.848938
# 1    104745.052692
# Name: 예매/취소금액, dtype: float64

# %%
# 조기예매 별 예매 금액 박스플롯
sns.boxplot(x='조기예매', y='예매/취소금액', data=df_musical)
plt.title('Prices of Early Buying')
plt.xlabel('Early Buying O X')
plt.ylabel('Prices')
plt.show()

# %%
# 조기예매 별 성별 분포 비교
df_musical.groupby('조기예매')['성별'].value_counts()
# Out:
# 조기예매  성별
# 0     2     16481
#       1      9593
#       0      4708
# 1     2     20223
#       1      6938
#       0      2293
# Name: count, dtype: int64

# %%
# 빈도수 계산
df_counts = df_musical.groupby(['조기예매', '성별']).size().reset_index(name='count')

# 막대 그래프 그리기
sns.barplot(x='조기예매', y='count', hue='성별', data=df_counts)
plt.title('Gender Distn by Early Buying')
plt.xlabel('Early buying')
plt.ylabel('Freq')
plt.show()

# %%
# 조기 예매 별 예매처 비교
df_musical.groupby('조기예매')['예매/취소방식명(관리시스템)'].value_counts()
# Out:
# 조기예매  예매/취소방식명(관리시스템)
# 0     모바일                19512
#       웹                  11270
# 1     모바일                17817
#       웹                  11637
# Name: count, dtype: int64

# %%
# 빈도수 계산
df_counts = df_musical.groupby(['조기예매', '예매/취소방식명(관리시스템)']).size().reset_index(name='count')

# 막대 그래프 그리기
sns.barplot(x='조기예매', y='count', hue='예매/취소방식명(관리시스템)', data=df_counts)
plt.title('Way Distn by Early Buying')
plt.xlabel('Early buying')
plt.ylabel('Freq')
plt.show()

# %% [markdown]
# ### 좌석등급

# %%
df_musical['좌석등급'].value_counts()
# Out:
# 좌석등급
# VIP석(170000), R석(140000), S석(110000), A석(80000)                                 12365
# VIP석(190000), R석(160000), S석(130000), A석(90000), B석(70000)                       4861
# VIP석(180000), R석(150000), S석(120000), A석(90000)                                  4801
# R석(66000), S석(55000)                                                             3969
# VIP석(160000), S석(120000), A석(80000)                                              3160
# 스탠딩(121000)                                                                      3107
# VIP석(150000), R석(130000), S석(90000), A석(60000)                                   2967
# VIP석(140000), OP석(130000), R석(110000), S석(90000), A석(70000)                      2773
# OP석(150000), VIP석(150000), R석(130000), S석(100000), A석(70000), B석(50000)          1850
# 전석(50000)                                                                        1572
# R석(77000), S석(55000)                                                             1562
# R석(70000), S석(50000)                                                             1509
# VIP석(150000), OP석(130000), R석(120000), S석(80000), A석(60000)                      1351
# VIP석(99000), R석(88000), S석(66000)                                                1307
# VIP석(150000), OP석(140000), R석(130000), S석(100000), A석(80000)                     1175
# 1층석(50000), 2층석(25000)                                                           1023
# VIP석(66000), S석(55000), A석(44000)                                                 915
# R석(70000), S석(60000)                                                              910
# R석(66000), S석(44000)                                                              838
# VIP석(160000), R석(130000), S석(100000), A석(70000)                                   744
# R석(40000), S석(30000)                                                              695
# R석(66000), S석(55000), 시야제한석(20000)                                                671
# R석(55000), S석(33000)                                                              549
# R석(55000), S석(44000), A석(33000)                                                   547
# R석(80000), S석(60000)                                                              523
# R석(88000), S석(66000), A석(44000)                                                   521
# R석(88000), S석(66000)                                                              444
# R석(65000)                                                                         442
# 전석(55000)                                                                         411
# R석(70000), S석(50000), A석(30000)                                                   323
# 전석(30000)                                                                         304
# 전석(70000)                                                                         289
# 전석(45000)                                                                         270
# WILD EVENT석(125000), WILDWILD석(99000), WILD석(77000), R석(66000), 시야방해석(60000)      229
# VIP석(60000), S석(50000), A석(40000)                                                 222
# 전석(40000)                                                                         191
# R석(30000), S석(20000)                                                              181
# 전석무료(0)                                                                           144
# 전석(35000)                                                                         139
# R석(66000), S석(66000), A석(55000)                                                   115
# 전석(66000)                                                                          91
# 전석(5000)                                                                           45
# VIP석(70000), R석(50000)                                                             32
# Alive(99000), Choice(77000)                                                        31
# 전석(60000)                                                                          30
# 전석(15000)                                                                          18
# alive석(99000), choice석(77000)                                                      12
# 전석(100000)                                                                          8
# Name: count, dtype: int64

# %% [markdown]
# ### 스타배우 영향

# %% [markdown]
# 스타배우 출연진이 영향이 있는지를 판별.
#
# 객석 x 장당 가격으로 파워 살펴보기
#
# 스타배우 칼럼 : 1이면 스타배우 극, 0이면 아님

# %%
lst=['최정원', '고준희', '신성록', '차승원', '진선규', '엄기준', '양지원', '나문희', '봉태규', '김선영', '김수미', '고두심', '염혜란',
     '문소리', '박정원', '박은석', '박해수', '박소담', '정성일', '지현준', '이순재', '신구', '홍승안', '정휘', '전성우', '박정복', '전동석',
     '강홍석', '조승우', '옥주현', '정선아', '민경아', '김선영', '최재림', '전미도', '카이', '김준수', '홍강호', '박효신', '박강현', '정성화', '규현',
     '박은태', '박성훈', '조정석', '김승우', '지창욱', '홍광호', '신영숙', '차지연', '지창욱', '한지상', '마이클리', '김소현', '박건형', '윤공주', '바다', '서범석', '아이비']

# 스타배우 칼럼 추가
# 스타배우 칼럼 추가
# 스타배우 칼럼 추가
df_musical['스타배우'] = df_musical['출연진내용'].apply(
    lambda x: 1 if isinstance(x, str) and any(actor in x.split(', ') for actor in lst) else 0
)

df_musical['스타배우'].value_counts()
# Out:
# <ipython-input-257-1c1802cae482>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_musical['스타배우'] = df_musical['출연진내용'].apply(
# 스타배우
# 0    32473
# 1    27763
# Name: count, dtype: int64

# %%
# 파워칼럼
# 파워 칼럼 계산: 장당금액 * 좌석 수
df_musical['파워'] = df_musical['장당금액'] * df_musical['좌석수']

# 스타배우 사용 여부에 따라 데이터 나누기
power_with_stars = df_musical[df_musical['스타배우'] == 1]['파워']
power_without_stars = df_musical[df_musical['스타배우'] == 0]['파워']

# 시각화
plt.figure(figsize=(12, 6))

# 히스토그램
plt.subplot(1, 2, 1)
sns.histplot(power_with_stars, bins=10, color='blue', kde=True, label='Star', stat='density')
sns.histplot(power_without_stars, bins=10, color='orange', kde=True, label='Nonstar', stat='density')
plt.title('Power Distn (Histogram)')
plt.xlabel('Power')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# <ipython-input-258-89212be45ad8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_musical['파워'] = df_musical['장당금액'] * df_musical['좌석수']
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
power_with_stars = df_musical[df_musical['스타배우'] == 1]['파워']
power_without_stars = df_musical[df_musical['스타배우'] == 0]['파워']

sns.boxplot(power_with_stars)
plt.title('Star Power')
plt.show()
sns.boxplot(power_without_stars)
plt.title('Nonstar Power')
plt.show()

# %% [markdown]
# ## 상관관계 파악

# %%
# 연극
# 데이터프레임의 수치형 칼럼만 선택
numeric_df = df_play.select_dtypes(include=[float, int])

# 상관관계 계산
correlation_matrix = numeric_df.corr()

# 상관관계 히트맵 시각화
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar_kws={"shrink": .8})
plt.title('Heatmap')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 뮤지컬
# 데이터프레임의 수치형 칼럼만 선택
numeric_df = df_musical.select_dtypes(include=[float, int])

# 상관관계 계산
correlation_matrix = numeric_df.corr()

# 상관관계 히트맵 시각화
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar_kws={"shrink": .8})
plt.title('Heatmap')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
